# %%
#Import the library of pandas

import pandas as pd
import numpy as np

# %%
#Read the dataset of movies

ds = pd.read_csv("popular_10000_movies_tmdb.csv")

# %%
#Show the dataset

ds
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist     4/5/2023
# 1     640146  Ant-Man and the Wasp: Quantumania    2/15/2023
# 2     502356        The Super Mario Bros. Movie     4/5/2023
# 3     868759                            Ghosted    4/18/2023
# 4     594767           Shazam! Fury of the Gods    3/15/2023
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   10/21/2016
# 9996   16774  Hellboy Animated: Sword of Storms   10/28/2006
# 9997   13564    Return to House on Haunted Hill    10/3/2007
# 9998  482204             My Sister-in-law's Job    8/31/2017
# 9999  444539                       The Bookshop   11/10/2017
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity     budget  \
# 0              7.4         619    5089.969   18000000
# 1              6.6        2294    4665.438  200000000
# 2              7.5        1861    3935.550  100000000
# 3              7.2         652    2791.532          0
# 4              6.8        1510    2702.593  125000000
# ...            ...         ...         ...        ...
# 9995           7.7        1220      10.774          0
# 9996           6.3          99      12.739          0
# 9997           5.6         263      12.769          0
# 9998           5.0           5      10.425          0
# 9999           6.5         382      12.525    5400000
#
#                                    production_companies
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...
# 1         ['Marvel Studios', 'Kevin Feige Productions']
# 2     ['Universal Pictures', 'Illumination', 'Ninten...
# 3                   ['Skydance Media', 'Apple Studios']
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...
# ...                                                 ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...
# 9996                ['IDT Entertainment', 'Film Roman']
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']
# 9998                                                 []
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...
#
# [10000 rows x 10 columns]

# %%
#Show the info about dataset

ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10000 non-null  int64
#  1   title                 10000 non-null  object
#  2   release_date          9979 non-null   object
#  3   genres                10000 non-null  object
#  4   original_language     10000 non-null  object
#  5   vote_average          10000 non-null  float64
#  6   vote_count            10000 non-null  int64
#  7   popularity            10000 non-null  float64
#  8   budget                10000 non-null  int64
#  9   production_companies  10000 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 781.4+ KB

# %%
ds['release_date'] = pd.to_datetime(ds['release_date'])
ds
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity     budget  \
# 0              7.4         619    5089.969   18000000
# 1              6.6        2294    4665.438  200000000
# 2              7.5        1861    3935.550  100000000
# 3              7.2         652    2791.532          0
# 4              6.8        1510    2702.593  125000000
# ...            ...         ...         ...        ...
# 9995           7.7        1220      10.774          0
# 9996           6.3          99      12.739          0
# 9997           5.6         263      12.769          0
# 9998           5.0           5      10.425          0
# 9999           6.5         382      12.525    5400000
#
#                                    production_companies
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...
# 1         ['Marvel Studios', 'Kevin Feige Productions']
# 2     ['Universal Pictures', 'Illumination', 'Ninten...
# 3                   ['Skydance Media', 'Apple Studios']
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...
# ...                                                 ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...
# 9996                ['IDT Entertainment', 'Film Roman']
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']
# 9998                                                 []
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...
#
# [10000 rows x 10 columns]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10000 non-null  int64
#  1   title                 10000 non-null  object
#  2   release_date          9979 non-null   datetime64[ns]
#  3   genres                10000 non-null  object
#  4   original_language     10000 non-null  object
#  5   vote_average          10000 non-null  float64
#  6   vote_count            10000 non-null  int64
#  7   popularity            10000 non-null  float64
#  8   budget                10000 non-null  int64
#  9   production_companies  10000 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 781.4+ KB

# %%
#Shape of dataset

ds.shape
# Out:
# (10000, 10)

# %%
#Check the null values

ds.isnull().sum()
# Out:
# id                       0
# title                    0
# release_date            21
# genres                   0
# original_language        0
# vote_average             0
# vote_count               0
# popularity               0
# budget                   0
# production_companies     0
# dtype: int64

# %%
#Drop the null values

ds.dropna(inplace=True)

# %%
#Check is there any null values

ds.isna().any()
# Out:
# id                      False
# title                   False
# release_date            False
# genres                  False
# original_language       False
# vote_average            False
# vote_count              False
# popularity              False
# budget                  False
# production_companies    False
# dtype: bool

# %%
#Check the null values

ds.isnull().sum()
# Out:
# id                      0
# title                   0
# release_date            0
# genres                  0
# original_language       0
# vote_average            0
# vote_count              0
# popularity              0
# budget                  0
# production_companies    0
# dtype: int64

# %%
#Show the shape of dataset

ds.shape
# Out:
# (9979, 10)

# %%
#show the first 10 row

ds.head(10)
# Out:
#        id                                    title release_date  \
# 0  758323                      The Pope's Exorcist   2023-04-05
# 1  640146        Ant-Man and the Wasp: Quantumania   2023-02-15
# 2  502356              The Super Mario Bros. Movie   2023-04-05
# 3  868759                                  Ghosted   2023-04-18
# 4  594767                 Shazam! Fury of the Gods   2023-03-15
# 5   76600                 Avatar: The Way of Water   2022-12-14
# 6  447365         Guardians of the Galaxy Volume 3   2023-05-03
# 7  934433                                Scream VI   2023-03-08
# 8  677179                                Creed III   2023-03-01
# 9  493529  Dungeons & Dragons: Honor Among Thieves   2023-03-23
#
#                                               genres original_language  \
# 0                  ['Horror', 'Mystery', 'Thriller']           English
# 1         ['Action', 'Adventure', 'Science Fiction']           English
# 2  ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                    ['Action', 'Comedy', 'Romance']           English
# 4       ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# 5         ['Science Fiction', 'Adventure', 'Action']           English
# 6         ['Science Fiction', 'Adventure', 'Action']           English
# 7                  ['Horror', 'Mystery', 'Thriller']           English
# 8                                ['Drama', 'Action']           English
# 9                 ['Adventure', 'Fantasy', 'Comedy']           English
#
#    vote_average  vote_count  popularity     budget  \
# 0           7.4         619    5089.969   18000000
# 1           6.6        2294    4665.438  200000000
# 2           7.5        1861    3935.550  100000000
# 3           7.2         652    2791.532          0
# 4           6.8        1510    2702.593  125000000
# 5           7.7        7853    2280.912  460000000
# 6           8.3         683    2520.308  250000000
# 7           7.3        1029    1862.283   35000000
# 8           7.3        1298    1894.044   75000000
# 9           7.5         964    1655.052  151000000
#
#                                 production_companies
# 0  ['Screen Gems', '2.0 Entertainment', 'Jesus & ...
# 1      ['Marvel Studios', 'Kevin Feige Productions']
# 2  ['Universal Pictures', 'Illumination', 'Ninten...
# 3                ['Skydance Media', 'Apple Studios']
# 4  ['New Line Cinema', 'The Safran Company', 'DC ...
# 5  ['20th Century Studios', 'Lightstorm Entertain...
# 6      ['Marvel Studios', 'Kevin Feige Productions']
# 7  ['Radio Silence', 'Project X Entertainment', '...
# 8  ['Metro-Goldwyn-Mayer', 'Proximity Media', 'Ba...
# 9  ['Entertainment One', 'Paramount', 'Allspark P...

# %%
#Show the last 10 row

ds.tail(10)
# Out:
#           id                                             title release_date  \
# 9990   10748                                     St. Trinian's   2007-12-21
# 9991  917269  The Witcher Season One Recap: From the Beginning   2021-12-17
# 9992  914216                                     The Lost King   2022-10-07
# 9993  823461                                     Good on Paper   2021-06-23
# 9994   94503    Tsubasa RESERVoir CHRoNiCLE: Tokyo Revelations   2007-11-16
# 9995  374473                                   I, Daniel Blake   2016-10-21
# 9996   16774                 Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564                   Return to House on Haunted Hill   2007-10-03
# 9998  482204                            My Sister-in-law's Job   2017-08-31
# 9999  444539                                      The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 9990            ['Comedy', 'Family', 'Science Fiction']           English
# 9991                                                 []           English
# 9992                                ['Drama', 'Comedy']           English
# 9993                              ['Comedy', 'Romance']           English
# 9994  ['Fantasy', 'Animation', 'Action', 'Adventure'...          Japanese
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity   budget  \
# 9990           5.9         418       7.770        0
# 9991           5.6           8       9.045        0
# 9992           6.5          51      11.138        0
# 9993           5.6         265       8.544        0
# 9994           7.2           6       7.949        0
# 9995           7.7        1220      10.774        0
# 9996           6.3          99      12.739        0
# 9997           5.6         263      12.769        0
# 9998           5.0           5      10.425        0
# 9999           6.5         382      12.525  5400000
#
#                                    production_companies
# 9990  ['Ealing Studios', 'Fragile Films', 'Entertain...
# 9991                                                 []
# 9992  ['Baby Cow Productions', 'BBC Film', 'Ingeniou...
# 9993  ['Burn Later Productions', 'Meridian Content',...
# 9994                                       ['Kodansha']
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...
# 9996                ['IDT Entertainment', 'Film Roman']
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']
# 9998                                                 []
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...

# %%
#Check the datatype 

ds.dtypes
# Out:
# id                               int64
# title                           object
# release_date            datetime64[ns]
# genres                          object
# original_language               object
# vote_average                   float64
# vote_count                       int64
# popularity                     float64
# budget                           int64
# production_companies            object
# dtype: object

# %%
#Show the name of all column

ds.columns
# Out:
# Index(['id', 'title', 'release_date', 'genres', 'original_language',
#        'vote_average', 'vote_count', 'popularity', 'budget',
#        'production_companies'],
#       dtype='object')

# %%
#Show the description of dataset

ds.describe()
# Out:
#                  id  vote_average    vote_count   popularity        budget
# count  9.979000e+03   9979.000000   9979.000000  9979.000000  9.979000e+03
# mean   3.143436e+05      6.338822   1530.054915    31.488106  1.954562e+07
# std    3.331747e+05      1.388166   2870.875959   111.528200  3.890194e+07
# min    5.000000e+00      0.000000      0.000000     7.219000  0.000000e+00
# 25%    1.220300e+04      5.900000    123.000000    13.531500  0.000000e+00
# 50%    1.925770e+05      6.500000    483.000000    17.616000  3.700000e+05
# 75%    5.604590e+05      7.100000   1561.000000    27.175500  2.200000e+07
# max    1.119921e+06     10.000000  33633.000000  5089.969000  5.793304e+08

# %%
# In[90]:


ds.info
# Out:
# <bound method DataFrame.info of           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity     budget  \
# 0              7.4         619    5089.969   18000000
# 1              6.6        2294    4665.438  200000000
# 2              7.5        1861    3935.550  100000000
# 3              7.2         652    2791.532          0
# 4              6.8        1510    2702.593  125000000
# ...            ...         ...         ...        ...
# 9995           7.7        1220      10.774          0
# 9996           6.3          99      12.739          0
# 9997           5.6         263      12.769          0
# 9998           5.0           5      10.425          0
# 9999           6.5         382      12.525    5400000
#
#                                    production_companies
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...
# 1         ['Marvel Studios', 'Kevin Feige Productions']
# 2     ['Universal Pictures', 'Illumination', 'Ninten...
# 3                   ['Skydance Media', 'Apple Studios']
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...
# ...                                                 ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...
# 9996                ['IDT Entertainment', 'Film Roman']
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']
# 9998                                                 []
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...
#
# [9979 rows x 10 columns]>

# %%
#Check the null values

ds.isnull().sum()
# Out:
# id                      0
# title                   0
# release_date            0
# genres                  0
# original_language       0
# vote_average            0
# vote_count              0
# popularity              0
# budget                  0
# production_companies    0
# dtype: int64

# %%
ds.drop_duplicates()
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity     budget  \
# 0              7.4         619    5089.969   18000000
# 1              6.6        2294    4665.438  200000000
# 2              7.5        1861    3935.550  100000000
# 3              7.2         652    2791.532          0
# 4              6.8        1510    2702.593  125000000
# ...            ...         ...         ...        ...
# 9995           7.7        1220      10.774          0
# 9996           6.3          99      12.739          0
# 9997           5.6         263      12.769          0
# 9998           5.0           5      10.425          0
# 9999           6.5         382      12.525    5400000
#
#                                    production_companies
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...
# 1         ['Marvel Studios', 'Kevin Feige Productions']
# 2     ['Universal Pictures', 'Illumination', 'Ninten...
# 3                   ['Skydance Media', 'Apple Studios']
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...
# ...                                                 ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...
# 9996                ['IDT Entertainment', 'Film Roman']
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']
# 9998                                                 []
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...
#
# [9979 rows x 10 columns]

# %%
mean_vote_average = ds['vote_average'].mean()
print (mean_vote_average)
# Out:
# 6.338821525202926

# %%
standard_deviation = ds['vote_average'].std()
standard_deviation
# Out:
# 1.3881662242465918

# %%
var = ds['vote_average'].var()
var
# Out:
# 1.927005466139039

# %%
correlation = ds['vote_average'].corr(ds['popularity'])
print (correlation)
# Out:
# 0.041080957530214506

# %%
id = ds.iloc[1:100]
id
# Out:
#           id                                            title release_date  \
# 1     640146                Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356                      The Super Mario Bros. Movie   2023-04-05
# 3     868759                                          Ghosted   2023-04-18
# 4     594767                         Shazam! Fury of the Gods   2023-03-15
# 5      76600                         Avatar: The Way of Water   2022-12-14
# ..       ...                                              ...          ...
# 96   1013860                   R.I.P.D. 2: Rise of the Damned   2022-11-15
# 97    829410                                             Sick   2022-09-11
# 98   1058732  The Simpsons Meet the Bocellis in Feliz Navidad   2022-12-15
# 99   1101799                                Queens on the Run   2023-04-14
# 100   873256                                      Kiss, Kiss!   2023-04-26
#
#                                                 genres original_language  \
# 1           ['Action', 'Adventure', 'Science Fiction']           English
# 2    ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                      ['Action', 'Comedy', 'Romance']           English
# 4         ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# 5           ['Science Fiction', 'Adventure', 'Action']           English
# ..                                                 ...               ...
# 96            ['Action', 'Comedy', 'Fantasy', 'Crime']           English
# 97                              ['Horror', 'Thriller']           English
# 98                   ['Animation', 'Family', 'Comedy']           English
# 99                                ['Comedy', 'Action']           Spanish
# 100                              ['Romance', 'Comedy']            Polish
#
#      vote_average  vote_count  popularity     budget  \
# 1             6.6        2294    4665.438  200000000
# 2             7.5        1861    3935.550  100000000
# 3             7.2         652    2791.532          0
# 4             6.8        1510    2702.593  125000000
# 5             7.7        7853    2280.912  460000000
# ..            ...         ...         ...        ...
# 96            6.6         462     206.501          0
# 97            6.3         132     206.397          0
# 98            5.2          36     194.059          0
# 99            7.0          83     204.485          0
# 100           6.9          15     361.900          0
#
#                                   production_companies
# 1        ['Marvel Studios', 'Kevin Feige Productions']
# 2    ['Universal Pictures', 'Illumination', 'Ninten...
# 3                  ['Skydance Media', 'Apple Studios']
# 4    ['New Line Cinema', 'The Safran Company', 'DC ...
# 5    ['20th Century Studios', 'Lightstorm Entertain...
# ..                                                 ...
# 96                    ['Universal 1440 Entertainment']
# 97   ['Miramax', 'Outerbanks Entertainment', 'Blumh...
# 98   ['Gracie Films', '20th Television', '20th Tele...
# 99                    ['Perro Azul', 'Selva Pictures']
# 100                                     ['Lightcraft']
#
# [99 rows x 10 columns]

# %%
def vote_average(i):
    if i > 6:
        return ("good")
    
    else: 
        return ("bad")

# %%
ds['vote_category'] = ds['vote_average'].apply(vote_average)

# %%
print(ds)
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity     budget  \
# 0              7.4         619    5089.969   18000000
# 1              6.6        2294    4665.438  200000000
# 2              7.5        1861    3935.550  100000000
# 3              7.2         652    2791.532          0
# 4              6.8        1510    2702.593  125000000
# ...            ...         ...         ...        ...
# 9995           7.7        1220      10.774          0
# 9996           6.3          99      12.739          0
# 9997           5.6         263      12.769          0
# 9998           5.0           5      10.425          0
# 9999           6.5         382      12.525    5400000
#
#                                    production_companies vote_category
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...          good
# 1         ['Marvel Studios', 'Kevin Feige Productions']          good
# 2     ['Universal Pictures', 'Illumination', 'Ninten...          good
# 3                   ['Skydance Media', 'Apple Studios']          good
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...          good
# ...                                                 ...           ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...          good
# 9996                ['IDT Entertainment', 'Film Roman']          good
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']           bad
# 9998                                                 []           bad
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...          good
#
# [9979 rows x 11 columns]

# %%
ds.shape
# Out:
# (9979, 11)

# %%
budget_median = ds['budget'].median()

# %%
ds['budget'] = np.where(ds['budget'] == 0, budget_median, ds['budget'])
ds
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity       budget  \
# 0              7.4         619    5089.969   18000000.0
# 1              6.6        2294    4665.438  200000000.0
# 2              7.5        1861    3935.550  100000000.0
# 3              7.2         652    2791.532     370000.0
# 4              6.8        1510    2702.593  125000000.0
# ...            ...         ...         ...          ...
# 9995           7.7        1220      10.774     370000.0
# 9996           6.3          99      12.739     370000.0
# 9997           5.6         263      12.769     370000.0
# 9998           5.0           5      10.425     370000.0
# 9999           6.5         382      12.525    5400000.0
#
#                                    production_companies vote_category
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...          good
# 1         ['Marvel Studios', 'Kevin Feige Productions']          good
# 2     ['Universal Pictures', 'Illumination', 'Ninten...          good
# 3                   ['Skydance Media', 'Apple Studios']          good
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...          good
# ...                                                 ...           ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...          good
# 9996                ['IDT Entertainment', 'Film Roman']          good
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']           bad
# 9998                                                 []           bad
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...          good
#
# [9979 rows x 11 columns]

# %%
ds.shape
# Out:
# (9979, 11)

# %%
ds
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity       budget  \
# 0              7.4         619    5089.969   18000000.0
# 1              6.6        2294    4665.438  200000000.0
# 2              7.5        1861    3935.550  100000000.0
# 3              7.2         652    2791.532     370000.0
# 4              6.8        1510    2702.593  125000000.0
# ...            ...         ...         ...          ...
# 9995           7.7        1220      10.774     370000.0
# 9996           6.3          99      12.739     370000.0
# 9997           5.6         263      12.769     370000.0
# 9998           5.0           5      10.425     370000.0
# 9999           6.5         382      12.525    5400000.0
#
#                                    production_companies vote_category
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...          good
# 1         ['Marvel Studios', 'Kevin Feige Productions']          good
# 2     ['Universal Pictures', 'Illumination', 'Ninten...          good
# 3                   ['Skydance Media', 'Apple Studios']          good
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...          good
# ...                                                 ...           ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...          good
# 9996                ['IDT Entertainment', 'Film Roman']          good
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']           bad
# 9998                                                 []           bad
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...          good
#
# [9979 rows x 11 columns]

# %%
ds.shape
ds
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity       budget  \
# 0              7.4         619    5089.969   18000000.0
# 1              6.6        2294    4665.438  200000000.0
# 2              7.5        1861    3935.550  100000000.0
# 3              7.2         652    2791.532     370000.0
# 4              6.8        1510    2702.593  125000000.0
# ...            ...         ...         ...          ...
# 9995           7.7        1220      10.774     370000.0
# 9996           6.3          99      12.739     370000.0
# 9997           5.6         263      12.769     370000.0
# 9998           5.0           5      10.425     370000.0
# 9999           6.5         382      12.525    5400000.0
#
#                                    production_companies vote_category
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...          good
# 1         ['Marvel Studios', 'Kevin Feige Productions']          good
# 2     ['Universal Pictures', 'Illumination', 'Ninten...          good
# 3                   ['Skydance Media', 'Apple Studios']          good
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...          good
# ...                                                 ...           ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...          good
# 9996                ['IDT Entertainment', 'Film Roman']          good
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']           bad
# 9998                                                 []           bad
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...          good
#
# [9979 rows x 11 columns]

# %%
ds.replace('[]', 'Company X', inplace=True)

# %%
ds
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity       budget  \
# 0              7.4         619    5089.969   18000000.0
# 1              6.6        2294    4665.438  200000000.0
# 2              7.5        1861    3935.550  100000000.0
# 3              7.2         652    2791.532     370000.0
# 4              6.8        1510    2702.593  125000000.0
# ...            ...         ...         ...          ...
# 9995           7.7        1220      10.774     370000.0
# 9996           6.3          99      12.739     370000.0
# 9997           5.6         263      12.769     370000.0
# 9998           5.0           5      10.425     370000.0
# 9999           6.5         382      12.525    5400000.0
#
#                                    production_companies vote_category
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...          good
# 1         ['Marvel Studios', 'Kevin Feige Productions']          good
# 2     ['Universal Pictures', 'Illumination', 'Ninten...          good
# 3                   ['Skydance Media', 'Apple Studios']          good
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...          good
# ...                                                 ...           ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...          good
# 9996                ['IDT Entertainment', 'Film Roman']          good
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']           bad
# 9998                                          Company X           bad
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...          good
#
# [9979 rows x 11 columns]

# %%
################ Q #####################

# %%
#Q1
movies_after2020 = ds.loc[ds['release_date'] > '1/1/2020', 'title']
movies_after2020
# Out:
# 0                                    The Pope's Exorcist
# 1                      Ant-Man and the Wasp: Quantumania
# 2                            The Super Mario Bros. Movie
# 3                                                Ghosted
# 4                               Shazam! Fury of the Gods
#                               ...
# 9974                                       Silver Skates
# 9975                                          Heart Shot
# 9991    The Witcher Season One Recap: From the Beginning
# 9992                                       The Lost King
# 9993                                       Good on Paper
# Name: title, Length: 2497, dtype: object

# %%
#Q2
movies_before2020 = ds.loc[ds['release_date'] < '1/1/2020', 'title']
movies_before2020
# Out:
# 37                     Guardians of the Galaxy Vol. 2
# 78      Demon Slayer: Kimetsu no Yaiba Sibling's Bond
# 82                  John Wick: Chapter 3 - Parabellum
# 83                            Guardians of the Galaxy
# 89           The Forbidden Legend: Sex & Chopsticks 2
#                             ...
# 9995                                  I, Daniel Blake
# 9996                Hellboy Animated: Sword of Storms
# 9997                  Return to House on Haunted Hill
# 9998                           My Sister-in-law's Job
# 9999                                     The Bookshop
# Name: title, Length: 7479, dtype: object

# %%
#Q3
vote_gt7 = ds.loc[ds['vote_average'] > 7, 'title'].head(15)
vote_gt7
# Out:
# 0                                   The Pope's Exorcist
# 2                           The Super Mario Bros. Movie
# 3                                               Ghosted
# 5                              Avatar: The Way of Water
# 6                      Guardians of the Galaxy Volume 3
# 7                                             Scream VI
# 8                                             Creed III
# 9               Dungeons & Dragons: Honor Among Thieves
# 10               The Last Kingdom: Seven Kings Must Die
# 12                                 John Wick: Chapter 4
# 15                         Puss in Boots: The Last Wish
# 22    Justice League x RWBY: Super Heroes & Huntsmen...
# 24                       Black Panther: Wakanda Forever
# 25                                              Mummies
# 33                                           Black Adam
# Name: title, dtype: object

# %%
#Q4
vote_lt4 = ds.loc[ds['vote_average'] < 4, 'title'].head(15)
vote_lt4
# Out:
# 23                                  Fast X
# 75          Yuku et la fleur de l’Himalaya
# 101                     The Little Mermaid
# 128       Transformers: Rise of the Beasts
# 150            Ryoma! The Prince of Tennis
# 184                              The Flash
# 209     Shabash Feluda: Gangtokey Gondogol
# 217                                 Strays
# 287           Cocaine Bear: The True Story
# 339    Spider-Man: Across the Spider-Verse
# 408                               The Rape
# 471                       No Hard Feelings
# 610                           Snake Beauty
# 641     Soltera, casada, viuda, divorciada
# 766                                 Barbie
# Name: title, dtype: object

# %%
#Q5
correlation = ds[['budget', 'popularity', 'vote_average']].corr()
correlation
# Out:
#                 budget  popularity  vote_average
# budget        1.000000    0.143559      0.071361
# popularity    0.143559    1.000000      0.041081
# vote_average  0.071361    0.041081      1.000000

# %%
# Line chart showing daily global streams of each song 
sns.lineplot(data=ds)
# Out:
# <Axes: >

# %%
#Q6
average_popularity_by_language = ds.groupby('original_language')['popularity'].mean()
average_popularity_by_language
# Out:
# original_language
# Arabic               43.169000
# Basque               55.991333
# Bengali              57.061500
# Catalan              23.054000
# Chinese              21.217533
# Czech                13.226000
# Danish               19.516133
# Dutch                52.384250
# Dzongkha             11.366000
# English              32.870146
# Estonian            197.218000
# Finnish              94.556000
# French               25.468060
# Galician             48.490000
# German               20.252476
# Greek                14.642750
# Hebrew               15.617000
# Hindi                15.083750
# Hungarian            14.230667
# Icelandic            77.614500
# Indonesian           24.875706
# Irish                12.405000
# Italian              23.938014
# Japanese             28.910547
# Kannada              12.449000
# Khmer                10.081000
# Korean               26.199825
# Macedonian           62.567000
# Malayalam            15.762667
# Norwegian            34.792969
# Norwegian Bokmal     16.935000
# Panjabi              10.082000
# Persian              27.867333
# Polish               43.287036
# Portuguese           18.492545
# Romanian             54.136000
# Russian              24.687174
# Serbian              21.419000
# Spanish              36.218121
# Sundanese             9.660000
# Swedish              24.620478
# Tagalog              25.523043
# Tamil                28.539300
# Telugu               27.553111
# Thai                 28.855077
# Turkish              34.906778
# Ukrainian            79.999750
# Vietnamese           21.236667
# cn                   22.407372
# sh                   13.323000
# xx                    9.991500
# Name: popularity, dtype: float64

# %%
#Q7
max_value = ds['vote_average'].max()
max_film = ds.loc[ds['vote_average'].idxmax(), 'title']
max_film
# Out:
# 'Orgasm Lecture 2'

# %%
#Q8
max_value = ds['budget'].max()
max_film = ds.loc[ds['budget'].idxmax(), 'title']
max_film
# Out:
# 'Operation Red Sea'

# %%
#Q9
min_value = ds['budget'].min()
min_film = ds.loc[ds['budget'].idxmin(), 'title']
min_film
# Out:
# 'Down'

# %%
#Q10
languages = ['English', 'Spanish', 'French']
num_movies = ds[ds['original_language'].isin(languages)].shape[0]
num_movies
# Out:
# 7869

# %%
#Q11
most_common_language = ds['original_language'].value_counts().idxmax()
most_common_language
# Out:
# 'English'

# %%
#Q12
num_movies = sum(ds['production_companies'] == 'Marvel Studios')
num_movies
# Out:
# 0

# %%
#Q13
less_common_company = ds['production_companies'].value_counts().idxmin()
less_common_company
# Out:
# "['Levins-Henenlotter', 'Shapiro-Glickenhaus Entertainment']"

# %%
#Q14
movie_title = "Evil Dead Rise"
production_companies = ds[ds['title'] == movie_title]['production_companies']
movie_title
# Out:
# 'Evil Dead Rise'

# %%
#Q15
max_vote_count = ds['vote_count'].max()
max_vote_count
# Out:
# 33633

# %%
#Q16

min_vote_count = ds['vote_count'].min()
min_vote_count
# Out:
# 0

# %%
#Q17
movie_title = "Avatar"
vote_count = ds[ds['title'] == movie_title]['vote_count'].values[0]
vote_count
# Out:
# 29040

# %%
#Q18
popularity_value = 1107.559
movie_title = ds[ds['popularity'] == popularity_value]['title'].values[0]
movie_title
# Out:
# 'Evil Dead Rise'

# %%
#Q19
movie_title = "Just Retired 2"
original_language = ds[ds['title'] == movie_title]['original_language'].values[0]
original_language
# Out:
# 'French'

# %%
#Q20
num_action_movies = ds[ds['genres'].str.contains('action', case=False)].shape[0]
num_action_movies
# Out:
# 2687

# %%
#Q21
num_movies_with_zero_vote_count = ds[ds['vote_count'] == 0].shape[0]
num_movies_with_zero_vote_count
# Out:
# 229

# %%
#Q22
highest_voted_genre = ds.groupby('genres')['vote_average'].mean().idxmax()
highest_voted_genre
# Out:
# "['Fantasy', 'Drama', 'Crime']"

# %%
#َ23

from datetime import datetime

current_year = datetime.now().year
five_years_ago = current_year - 5

num_movies_last_five_years = ds[ds['release_date'].dt.year >= five_years_ago].shape[0]
num_movies_last_five_years
# Out:
# 3435

# %%
#َ24

# استخراج أسماء شركات الإنتاج المميزة
production_companies = ds['production_companies'].unique()

# عرض أسماء شركات الإنتاج
for company in production_companies:
    print(company)
# Out:
# ['Screen Gems', '2.0 Entertainment', 'Jesus & Mary', 'Worldwide Katz', 'Loyola Productions', 'FFILME.RO']
# ['Marvel Studios', 'Kevin Feige Productions']
# ['Universal Pictures', 'Illumination', 'Nintendo']
# ['Skydance Media', 'Apple Studios']
# ['New Line Cinema', 'The Safran Company', 'DC Films', 'Warner Bros. Pictures']
# ['20th Century Studios', 'Lightstorm Entertainment']
# ['Radio Silence', 'Project X Entertainment', 'Spyglass Media Group', 'Paramount']
# ['Metro-Goldwyn-Mayer', 'Proximity Media', 'Balboa Productions', 'Outlier Society Productions', 'Chartoff-Winkler Productions']
# ['Entertainment One', 'Paramount', 'Allspark Pictures', 'Sierra/Affinity']
# ['Carnival Films']
# ['Walt Disney Pictures', 'Whitaker Entertainment']
# ['Thunder Road', '87Eleven', 'Summit Entertainment', 'Studio Babelsberg', 'Lionsgate']
# ['New Line Cinema', 'Ghost House Pictures', 'Renaissance Pictures', 'Pacific Renaissance Pictures', 'Wild Atlantic Pictures']
# ['Universal Pictures', 'Brownstone Productions', 'Lord Miller Productions']
# ['DreamWorks Animation', 'Universal Pictures']
# ['Happy Madison Productions', 'Echo Films', 'Vinson Films', 'Endgame Entertainment']
# ['Inoxy Films', 'Nolita']
# ['Johan Nijenhuis & Co (NL)', 'EO  -  EO (NL)']
# ['Ikiru Films', 'Atresmedia', 'Warner Bros. Entertainment España']
# ['Raimi Productions', 'Beck/Woods', 'Bron Studios', 'Columbia Pictures']
# Company X
# ['Warner Bros. Animation', 'Rooster Teeth Productions', 'Warner Bros. Home Entertainment Group']
# ['Universal Pictures', 'Original Film', 'One Race', 'Perfect Storm Entertainment']
# ['Marvel Studios']
# ['Warner Bros. Entertainment España', '4 Cats Pictures', 'Moomios Movie AIE', 'Anangu Grup SL', 'C.O.R.E. Feature Animation', 'Atresmedia']
# ['See At Film']
# ['Jagged Edge Productions', 'ITN Studios']
# ['The Asylum', 'Emerald City Films']
# ['26th Street Pictures', 'Pimienta Films']
# ['Thomasville Pictures', 'Highland Film Group', 'Saban Films', 'Short Porch Pictures', 'Streamline Global', 'Bay Point Media', 'Volition Media Partners']
# ['New Line Cinema', 'Flynn Picture Company', 'DC Films', 'Seven Bucks Productions']
# ['Atomic Monster', 'Blumhouse Productions', 'Divide / Conquer', 'Universal Pictures']
# ['Czech Anglo Productions', 'Third Day Production', 'MBM3 Films']
# ['Vanishing Angle']
# ['Cinereach', 'Strongman', 'Chiodo Bros. Productions', 'You Want I Should, LLC', 'Human Woman', 'Sunbeam TV & Films']
# ['BTF media']
# ['Stage 6 Films', 'Toei Animation']
# ['Blinding Edge Pictures', 'Universal Pictures', 'FilmNation Entertainment', 'Wishmore', 'Perfect World Pictures', 'dentsu']
# ['8bit', 'Bandai Namco Filmworks', 'Magic Capsule', 'Sony Music Solutions', 'Bandai Spirits', 'Kodansha', 'MICRO MAGAZINE', 'Bandai Namco Music Live', 'Nippon BS Broadcasting', 'ADK Marketing Solutions', 'Nippon Television Network Corporation', 'Lantis']
# ['MadRiver Pictures', 'di Bonaventura Pictures', 'G-BASE', 'Olive Hill Media', 'Riverstone Pictures']
# ['Premiere Entertainment Group']
# ['Lionsgate', 'Mandeville Films', 'Nuyorican Productions', 'Maximum Effort']
# ['Subzero Film Entertainment', 'Good Chaos', 'Stage 6 Films', 'Lionsgate']
# ['Ulysses Filmproduktion', 'Cantilever Media', 'Filmförderung Hamburg Schleswig-Holstein', 'MEDIA sub-programme of Creative Europe', 'FFA', 'Narrativia', 'Studio Rakete', 'Squeeze', 'Red Star 3D', 'Viva Films']
# ['Tea Shop Productions', 'Capstone Pictures', 'BuzzFeed Studios']
# ['Creativ Studios']
# ['NoDancingToday']
# ['Skybound Entertainment', 'Universal Pictures', 'Giant Wildcat']
# ['DAX Production', 'Pony Canyon', 'Nichion', 'Bibury Animation Studios', 'Nippon BS Broadcasting', 'GYAO', 'Kodansha', 'Good Smile Film', 'Bushiroad', 'MAGNET']
# ['AGC Studios', 'Bigscope Films', 'Moonriver Content']
# ['Lionsgate', 'Gold Circle Films', 'Confluence Productions']
# ['ACE entertainment', 'Ari Entertainment', 'Grindstone Entertainment Group']
# ['The Asylum']
# ['DC Entertainment', 'Warner Bros. Animation', 'Warner Bros. Home Entertainment Group']
# ['BAKKEN RECORD', 'dentsu', 'Toei Company', 'KDDI', 'KADOKAWA', 'Tatsunoko Production', 'OBS', 'Oita Godo Shimbun', 'Hayakawa Publishing', 'nekojarashi', 'MOTION GALLERY']
# ['TMS Entertainment', 'dentsu', 'Toei Company', 'KDDI', 'KADOKAWA', 'Tatsunoko Production', 'OBS', 'Oita Godo Shimbun', 'Hayakawa Publishing', 'nekojarashi', 'MOTION GALLERY']
# ['Skydance Media', 'Don Simpson/Jerry Bruckheimer Films', 'Paramount']
# ['20th Century Studios']
# ['Funky Films', 'Paralelo Films']
# ['UM Group']
# ['Marvel Studios', 'Pascal Pictures', 'Columbia Pictures']
# ['Motion Blur']
# ['Nadie es Perfecto']
# ['Climax Studios']
# ['Mr. Fields and Friends', 'Atresmedia', 'Bambú Producciones', 'Movistar+']
# ['Original Film', 'Blur Studio', 'Marza Animation Planet', 'Paramount', 'SEGA']
# ['Vivement lundi !', 'Nadasdy Film', 'Les Films du Nord', 'Artémis Productions', 'La Boîte, ... Productions']
# ['Warner Bros. Animation', 'DC Entertainment', 'Warner Bros. Home Entertainment Group']
# ['Animal Logic', 'Netflix Animation', 'Village Roadshow Pictures', 'Pistor Productions']
# ['ufotable']
# ['SP Media Group', 'Steven Paul Production', 'Front Street Pictures']
# ['Dark Age Cinema', 'Fuzz on the Lens Productions', 'Bloody Disgusting']
# ['20th Digital Studio']
# ['Thunder Road', 'Lionsgate', '87Eleven']
# ['Horror Wasteland Pictures International']
# ['Amblin Entertainment', 'Universal Pictures']
# ['ufotable', 'Aniplex', 'Shueisha', 'STUDIO MAUSU', 'TOHO']
# ['HartBeat Productions']
# ['Marvel Studios', 'Kevin Feige Productions', 'Troll Court Entertainment']
# ['Universal Media Studios', 'Twin Co. Ltd.', 'My Way Film Company']
# ['Paramount Players', 'Temple Hill Entertainment', 'Paramount']
# ['Paramount', 'Project X Entertainment', 'Radio Silence', 'Spyglass Media Group']
# ['Working Title Films', 'The Roald Dahl Story Company']
# ['AMP International', 'Disney Concerts', 'Fulwell 73', 'Live Nation Productions']
# ['74 Entertainment', 'Viaplay']
# ['TriStar Pictures', 'JuVee Productions', 'Jack Blue Productions', 'Entertainment One', 'Welle Entertainment']
# ['Universal 1440 Entertainment']
# ['Miramax', 'Outerbanks Entertainment', 'Blumhouse Productions']
# ['Gracie Films', '20th Television', '20th Television Animation']
# ['Perro Azul', 'Selva Pictures']
# ['Lightcraft']
# ['Walt Disney Pictures', 'Lucamar Productions', 'Marc Platt Productions']
# ['Film Bridge International', 'The Motus Studios']
# ['CoMix Wave Films', 'Story', 'Lawson Entertainment', 'East Japan Marketing & Communications', 'voque ting', 'KADOKAWA', 'Aniplex', 'TOHO']
# ['Fabula', 'Amazon Studios']
# ['Hex Movie']
# ['JBJ Film', 'Three Brothers Production']
# ['87North Productions', 'Universal Pictures']
# ['Thunder Road', '87Eleven', 'Summit Entertainment']
# ['Original Film', 'One Race', 'Perfect Storm Entertainment', 'Universal Pictures', 'Roth-Kirschenbaum Films']
# ['Huevocartoon Producciones']
# ['Voltage Pictures']
# ['Disruptiva Films', 'Machete Producciones', 'Maligno Gorehouse', 'Terminal']
# ['6th & Idaho', 'Dylan Clark Productions', 'DC Films', 'Warner Bros. Pictures']
# ['Skydance Animation', 'Skydance Animation East', 'Skydance Animation']
# ['Deeper Water Films', 'Madman Entertainment', 'Altitude Media']
# ['Born to Burn Films', 'Millenium Media Group', 'Millennium Films']
# ['Playtone', 'SF Studios', '2DUX²', 'Artistic Films', 'Columbia Pictures']
# ['Chris Morgan Productions', 'Seven Bucks Productions', 'Universal Pictures']
# ['SkyFrame']
# ['Pokeepsie Films']
# ['RocketScience', 'Amusement Park Films']
# ['The Safran Company', '3 in the Box', 'Ketchup Entertainment']
# ['The Jim Henson Company', 'ShadowMachine', 'Double Dare You Productions']
# ['KD Studios']
# ['Skydance Media', 'Paramount', 'di Bonaventura Pictures', 'Bay Films', 'Hasbro', 'New Republic Pictures', 'Tom DeSanto/Don Murphy Production']
# ['Goldrush Entertainment', 'Yale Productions', 'Lucky 13 Productions']
# ['Dune Entertainment', 'Lightstorm Entertainment', '20th Century Fox', 'Ingenious Media']
# ['Black Label Media', 'STX Entertainment', 'Columbia Pictures', 'Stage 6 Films']
# ['Universal Pictures', 'Illumination']
# ['Roxwell Films', 'Three Point Capital']
# ['Mompracem', 'Astorina S.A.C.', 'Emilia-Romagna Film Commission', 'RAI Cinema']
# ['A-1 Pictures', 'SAO-P Project']
# ['One Dollar Production Limited', 'Local Production', 'Film Workshop', 'Tai Seng Entertainment', 'Keyfilms Roma', 'Medusa Film', 'Lucky Red']
# ['Walt Disney Pictures', 'Pixar']
# ['Cook and Muse Entertainment', 'Head First Productions', 'Muse Entertainment', 'Radius Squared Media Group']
# ['Walt Disney Animation Studios', 'Walt Disney Pictures']
# ['A24', 'Protozoa Pictures']
# ['Millennium Films', 'Decal']
# ['Furia Films']
# ['TriStar Pictures', 'FilmDistrict', 'Ghost House Pictures']
# ['Miramax', 'STX Entertainment', 'Toff Guy Films', 'Tencent Pictures', 'AZ Celtic Films']
# ['Columbia Pictures', 'Atlas Entertainment', 'PlayStation Productions', 'Arad Productions', 'Studio Babelsberg', 'Deutscher Filmförderfonds', 'Medienboard Berlin-Brandenburg']
# ['Mutiny Films']
# ['The Monk Studios', 'GAGA Corporation', 'KEICA']
# ['Lotura Films', 'EiTB']
# ['Highland Film Group', 'Rather Good Films', 'Ingenious Media', 'Scarlet Productions', 'Ashland Hill Media Finance']
# ['TOHO', 'Shin-Ei Animation', 'Fujiko Productions', 'Shogakukan', 'TV Asahi', 'Shogakukan-Shueisha Productions', 'Shirogumi', 'Robot Communications', 'dentsu', 'Asatsu-DK']
# ['Lovely Productions', 'Wild Swim Films', 'Epicmedia']
# ['Sony Pictures Animation', 'Sony Pictures', 'MRC']
# ['DreamWorks Animation']
# ['Orwo Studios (US)', 'Screen Media Films', 'Black Hangar Studios']
# ['Song Sound Production']
# ['Colorado Film']
# ['A Contracorriente Films']
# ['Walt Disney Pictures', 'Walden Media', 'C.S. Lewis Company']
# ['New Line Cinema', 'Silver Pictures', 'Sweetpea Entertainment', 'Behaviour Worldwide', 'MDP Worldwide', 'Stillking Films']
# ['DreamWorks Pictures', 'Pacific Data Images', 'DreamWorks Animation']
# ['Lanistar Media', 'Motion Content Group', 'CJ Entertainment Turkey']
# ['Toei Animation']
# ['Bandidos Films']
# ['Original Film', 'One Race', 'Universal Pictures']
# ['Epica Pictures INC']
# ['RVK Studios', 'Will Packer Productions', 'Universal Pictures']
# ['Warner Bros. Japan']
# ['87Eleven', 'DefyNite Films', 'MJW Films', 'Thunder Road']
# ['828 Productions', 'Buffalo 8', '828 Media Capital', 'VMI Worldwide', 'ABS Payroll & Production Accounting Services', 'Project Indie Hope']
# ['Toei Animation', 'Marza Animation Planet']
# ['Beyond C.', 'Graphinica', 'STUDIO4℃']
# ['Vendian Entertainment', 'Summit Entertainment', 'Cross Creek Pictures', 'IM Global', 'Screen Australia', 'Screen NSW', 'Permut Presentations', 'Pandemonium', 'Demarest Films', 'Lionsgate']
# ['Ekipa Sp. z o.o.', 'Future Space', 'Next Film', 'TVN']
# ['Altitude Film Sales', 'Ingenious Media']
# ['TOHO', 'Shirogumi', 'Robot Communications', 'Shin-Ei Animation']
# ['Licensing Brands', 'Luminescence']
# ['Marvel Entertainment', 'Columbia Pictures', 'Pascal Pictures', 'Matt Tolmach Productions', 'Avi Arad Productions', 'Sony Pictures']
# ['Walt Disney Pictures', 'Josephson Entertainment', 'Right Coast']
# ['87North Productions', 'Columbia Pictures']
# ['Warner Bros. Pictures', 'Double Dream', 'The Disco Factory', 'DC Films']
# ['Legendary Pictures']
# ['Warner Bros. Pictures', 'Heyday Films', '1492 Pictures']
# ['Voltage Pictures', 'Wattpad', 'Vertical Entertainment', 'Ethea Entertainment', 'CalMaple Films']
# ['Breakable Films']
# ['VIS', '11:11 Films & TV']
# ['Caribbean Films']
# ['Arcana Studio', '308 Enterprises', 'BondIt Media Capital', 'Buffalo 8']
# ['CoMix Wave Films', 'TOHO', 'KADOKAWA', 'East Japan Marketing & Communications', 'AMUSE', 'voque ting', 'Lawson Entertainment', '4Kids Entertainment']
# ['Pegasus Pictures', 'Stöð 2', 'SamFilm']
# ['Hollywood Pictures', 'Cinergi Pictures Entertainment', 'Allied Filmmakers', 'Lightmotive']
# ['Walt Disney Pictures', 'Gunn Films', 'Marc Platt Productions']
# ['Constantin Film', 'JB Pictures', 'Spark Productions', 'Wattpad WEBTOON Studios']
# ['Hutch Parker Entertainment', 'Speck Gordon', 'Eagle Pictures', 'TSG Entertainment', 'Columbia Pictures', 'Sony Pictures']
# ['Paramount', 'Fortis Films', '3dot Productions', 'Exhibit A Film']
# ['Mattel Television']
# ['Vivamax']
# ['A24', 'Little Lamb Productions']
# ['Walt Disney Pictures', 'Walt Disney Animation Studios']
# ['Warner Bros. Pictures', 'Heyday Films', 'Brazil Production Services']
# ['Morena Films', 'Backup Media', 'Cerdita AIE']
# ['Yong Film']
# ['Roxwell Films']
# ['Roadshow Films', 'Eskay Movies']
# ['Film Tank', 'Cinépolis Producciones', 'Cinema Máquina']
# ['Warner Bros. Japan', 'SQUARE ENIX', 'Oxybot']
# ['Warner Bros. Pictures', 'The Stone Quarry', 'Atlas Entertainment', 'Access Entertainment', 'Dune Entertainment', 'DC Films']
# ['Dark Castle Entertainment', 'Entertainment One', 'Eagle Vision']
# ['Zoé & Cie', 'Belga Productions', 'Marvelous Productions', 'Amazon']
# ['Agat Films & Cie / Ex Nihilo', 'Diaphana Films', 'Topkapi Films', 'Versus Production', 'Menuet', 'Eurimages', 'Les Films Velvet', 'VTM', 'RTBF', 'Vlaams Audiovisueel Fonds', 'Nederlands Fonds voor de Film', 'Canal+', 'Ciné+', 'Sacem', "Centre du Cinéma et de l'Audiovisuel de la FWB", 'La Culture avec la Copie Privée', 'Casa Kafka Pictures', 'Screen Flanders', 'Lumière', 'The Match Factory']
# ['Universal Pictures', 'PictureStart', 'Lord Miller Productions', 'Gloria Sanchez Productions', 'Rabbit Hole Productions', 'Universal Animation Studios']
# ['Beyond C.', 'Graphinica', 'STUDIO4℃', 'Warner Bros. Japan']
# ['Nikkatsu Corporation']
# ['MTV Entertainment Studios', 'MGM Television', 'First Cause', 'Capital Arts Entertainment']
# ['Iconoclast', 'Lyly Films']
# ['Toei Animation', 'Shueisha', 'Fuji Television Network', 'Bandai Namco Entertainment', 'Bird Studios', 'Toei Company']
# ['Universal Pictures', 'Blumhouse Productions', 'Crooked Highway']
# ['Focus Features', 'Laika Entertainment', 'Pandemonium']
# ['Zinc Entertainment Inc.', 'Skyline Films', 'Studio Hamburg WorldWide Pictures', 'Sweetpea Entertainment']
# ['T-Street Productions']
# ['Focus Features', 'Michael De Luca Productions', 'Trigger Street Productions']
# ['Warner Animation Group', 'DC Entertainment', 'Seven Bucks Productions', 'Animal Logic', 'Warner Bros. Pictures']
# ['Les Films du Scarabée', 'Cinétéléfilms', 'France Média']
# ['Working Title Films', 'Instinct Productions', 'StudioCanal']
# ['Aathi Thiraikalam']
# ['Warner Bros. Pictures', 'Heyday Films']
# ['Good Thing Going Productions']
# ['Grade A Entertainment', 'Dayday Films', 'FilmNation Entertainment', 'Fox Searchlight Pictures']
# ['Nickelodeon Movies', '9 Story Media Group', 'Brown Bag Films']
# ['Bloody Disgusting', 'Cinepocalypse', 'Studio71', 'Shut Up & Colour Pictures', 'Yer Dead Productions']
# ['Rizoma Films', 'Frontera Films', 'Leyenda']
# ['Universal Pictures', 'Perfect World Pictures']
# ['Splash Entertainment']
# ['Vertical Entertainment']
# ['Atomic Monster', 'Broken Road Productions', 'New Line Cinema']
# ['Clear Horizon Entertainment', 'SSS Entertainment']
# ['21 Laps Entertainment', '1492 Pictures', 'Walt Disney Pictures']
# ['Epix', 'Blumhouse Television']
# ['River Bay Films', 'Ingenious Media', 'Lucky 13 Productions', 'The Avenue Entertainment', 'Convergence Entertainment', 'Diamond Film Productions', 'Highland Film Group', 'Pimienta', 'BondIt', 'SSS Entertainment', 'Verdi Productions', 'VVS Films']
# ['El Viaje Films', '4 à 4 Productions', 'Prisma Cine', 'Magoya Films']
# ['DVV Entertainment', 'Pen Studios', 'Lyca Productions']
# ['Dimension Films', 'Woods Entertainment']
# ['Feigco Entertainment']
# ['Toei Animation', 'Toei Company']
# ['Killer Films', 'Metro-Goldwyn-Mayer', 'Elevation Pictures']
# ['BondIt Media Capital', 'Buffalo 8', 'Lionsgate']
# ['Filmology Finance', 'Moviebox']
# ['Metro-Goldwyn-Mayer', 'New Line Cinema', 'Chartoff-Winkler Productions']
# ['Bardel Entertainment', 'Walt Disney Pictures', '20th Century Studios']
# ['EMJAG Productions', 'Red Granite Pictures', 'Appian Way', 'Sikelia Productions']
# ['Studio Deen', 'Kitty Films']
# ['Pixar']
# ['Head Gear Films', 'Metrol Technology', 'Kreo Films FZ', 'Trigger Films', 'Red Production', 'Evolution Pictures']
# ['Renaissance Pictures']
# ['Walt Disney Pictures', 'Weimaraner Republic Pictures']
# ['Open Window Productions', 'BN Films', 'Itaca Films', 'Itaca Films']
# ['Legendary Pictures', 'Syncopy', 'Lynda Obst Productions']
# ['Centropolis Entertainment', 'Street Entertainment', 'Lionsgate', 'AGC Studios', 'Summit Entertainment', 'Huayi Brothers Pictures', 'UK Moonfall LLP', 'Tencent Pictures']
# ['Walt Disney Pictures', 'Silver Screen Partners IV', 'Walt Disney Feature Animation']
# ['Draco Films']
# ['Warner Bros. Pictures', '1492 Pictures', 'Heyday Films', 'P of A Productions Limited']
# ['BuzzFeed Studios', 'Lionsgate', 'CR8IV DNA']
# ['MAPPA', 'Shueisha', 'Sumzap', 'MBS', 'dugout', 'TOHO']
# ['Monkeypaw Productions', 'Universal Pictures', 'dentsu']
# ['Hoodoo Productions']
# ['Burning Sky Films', 'Snakebyte Productions and Entertainment Group', 'Willow Pictures', 'Scarlett Pictures', 'Tip-Top Productions', 'Skipstone Pictures']
# ['BondIt Media Capital', 'CaliWood Pictures', 'R-Lines Productions', 'Three Point Capital']
# ['Paramount', 'Platinum Dunes', 'Sunday Night', 'Buffalo FilmWorks']
# ['Warner Bros. Pictures', 'Heyday Films', 'Patalex IV Productions Limited']
# ['ITN Productions', 'Brownstone Productions']
# ['New Regency Pictures', 'Focus Features', 'Perfect World Pictures', 'Square Peg']
# ['Horipro', 'Nintendo', 'Nippon Television Music Corporation', 'VAP', 'Grouper Productions', 'Shochiku']
# ['Big Dreams Entertainment', 'Swirl Films', 'Lifetime']
# ['di Bonaventura Pictures', 'Tom DeSanto/Don Murphy Production', 'Ian Bryce Productions', 'Paramount']
# ['CalMaple Films', 'Wattpad', 'Offspring Entertainment', 'Diamond Film Productions', 'Voltage Pictures', 'Frayed Pages Entertainment']
# ['A Private View', 'Bord Cadre Films', 'Heretic', 'Schiwago Film', 'Sovereign Films', 'Focus Features', 'Bankside Films']
# ['Paramount', 'Marc Platt Productions', 'Material Pictures', 'C2 Motion Picture Group', 'Wild Chickens', 'Organism Pictures']
# ['Pixar', 'Walt Disney Pictures']
# ['Lightbox Animation Studios', '4 Cats Pictures', 'Ikiru Films', 'Telecinco Cinema']
# ['Fado Filmes', 'Les Films Manuel Munz']
# ['Low Spark Films', 'Evil Hag Productions']
# ['Phantom Four', 'Spyglass Media Group']
# ['Metro-Goldwyn-Mayer', 'Balboa Productions']
# ['Paul Thiltges Distributions', 'Endorfilm', 'Kinorama', 'Bord Cadre Films', 'Sovereign Films', 'Aqua Carpatica', 'ArteKino International', 'Covalact', 'Hrvatski Audiovizualni Centar', 'Czech Film Fund', 'Film Fund Luxemburg', 'microFILM']
# ['DC Films', 'Atlas Entertainment', 'The Safran Company', 'Warner Bros. Pictures']
# ['Black Bear Pictures', 'Welle Entertainment', 'Saville Productions', 'Open Road Films']
# ['Lionsgate', 'Color Force']
# ['Columbia Pictures', 'Avi Arad Productions', 'Matt Tolmach Productions']
# ['The Thinklab', 'Kapers Animation', '3 Doubles Producciones', 'Particular Crowd', 'RTVE']
# ['Walt Disney Pictures', 'Walt Disney Feature Animation']
# ['Fowler Media']
# ['Independent']
# ['Skydance Media', 'Phantom Four', 'Lit Entertainment Group']
# ['Paramount', 'Alfran Productions']
# ['TMU Pictures']
# ['Screen Gems', 'Mid Atlantic Films', 'TSG Entertainment']
# ['Warner Bros. Animation', 'Turner Entertainment']
# ['Walt Disney Pictures', 'Jerry Bruckheimer Films']
# ['Legendary Pictures', 'PCMA Productions']
# ['Broadway Video', 'Paramount', 'M.G. Films']
# ['Universal Pictures', 'DreamWorks Animation']
# ['SP Media Group', 'Wonder Street', 'Front Street Pictures']
# ['G.R.P. Cinematografica', 'Cinestampa Internazionale']
# ['New Line Cinema', 'The Safran Company', 'Atomic Monster']
# ['Marv Films', 'AI Film', 'Unigram', 'Cloudy Productions']
# ['Constantin Film', 'Davis Films', 'Screen Gems', 'CAPCOM', 'Impact Pictures']
# ['Frontier Pictures']
# ['Paramount', '20th Century Fox', 'Lightstorm Entertainment']
# ['Columbia Pictures', 'Sony Pictures Animation', 'Marvel Entertainment', 'Lord Miller Productions', 'Pascal Pictures', 'Avi Arad Productions']
# ['Walt Disney Pictures', 'Jerry Bruckheimer Films', 'Moving Picture Company']
# ['FilmNation Entertainment', 'Metro-Goldwyn-Mayer', 'Free Association']
# ['Andrew Stevens Entertainment', 'Eyevox Entertainment', 'Milestone Studios']
# ['Atresmedia']
# ['Greenway Entertainment']
# ['Ingenious Media', 'Gotham Group', 'Dayday Films', 'Temple Hill Entertainment', 'TSG Entertainment', '20th Century Fox']
# ['BondIt Media Capital', 'Contemptible Entertainment', 'The Squid Farm']
# ['The Contents On', 'Contents G', 'Cheum Film', 'Finecut']
# ['Hillin Entertainment', 'BGG Capital', 'Film Bridge International']
# ['Paramount', 'Jerry Bruckheimer Films']
# ['OGM Pictures']
# ['Lucasfilm Ltd.', '20th Century Fox']
# ['Bona Film Group']
# ['Cilantro Films']
# ['20th Century Fox', "The Donners' Company", 'Genre Films']
# ['Filmkameratene', 'REinvent Studios']
# ['Sanai Pictures', 'Artist Company']
# ['New Line Cinema', 'Sunswept Entertainment', 'Metro-Goldwyn-Mayer']
# ['308 Enterprises', 'Arcana Studio', 'BondIt Media Capital', 'Buffalo 8 Productions', 'Grandave Capital', 'Yale Productions', 'Saban Films']
# ['DreamWorks Animation', 'Mad Hatter Entertainment']
# ['Bird Studios', 'Toei Animation', 'Toei Company']
# ['Marvel Entertainment', 'Columbia Pictures', 'Matt Tolmach Productions', 'Avi Arad Productions']
# ['Pierrot']
# ['Fox International Productions', 'Toei Animation', 'Fizz Sound Creation', 'Toei Company', '20th Century Fox', '20th Century Fox Animation']
# ['Incubo Films', 'The Rancon Company']
# ['Netflix']
# ['TMS Entertainment', 'Shogakukan', 'Yomiuri Telecasting Corporation', 'Nippon Television Network Corporation', 'Shogakukan-Shueisha Productions', 'TOHO']
# ['Skydance Media', 'H2L Media "AKA" Mutual Film Company', 'H2L Media Group', 'TC Productions', 'Mutual Films', 'Paramount']
# ['New Line Cinema', 'The Safran Company', 'Seven Bucks Productions', 'DC Films', 'Warner Bros. Pictures']
# ['PassionFlix']
# ['Nolita', 'Versus Production', 'Inoxy Films']
# ['Salmira Productions', 'Little Lamb Productions', 'Epic', 'UpperRoom Productions']
# ['Touchstone Pictures', 'ImageMovers', 'Angry Films', 'Kontsept Film Company', 'Revolution Sun Studios', 'DreamWorks Pictures', 'Reliance Entertainment', '21 Laps Entertainment']
# ['Hex Studios']
# ['Voltage Pictures', 'Offspring Entertainment', 'Frayed Pages Entertainment', 'Wattpad']
# ['Warner Bros. Pictures', 'Village Roadshow Pictures', 'Venus Castina Productions']
# ['Caudillo Cine', 'Estudio Giz', 'Oro Films']
# ['Cross Creek Pictures', 'Le Grisbi Productions']
# ['Madhouse', 'Discotek Media']
# ['Lonetree Entertainment', 'Columbia Pictures', 'Village Roadshow Pictures', 'Escape Artists', 'LStar Capital', 'Mace Neufeld Productions']
# ['Columbia Pictures', 'Lord Miller Productions', 'Pascal Pictures', 'Sony Pictures Animation', 'Avi Arad Productions']
# ['Berlanti Productions', '21 Laps Entertainment', 'Maximum Effort', 'Lit Entertainment Group', '20th Century Studios']
# ['30WEST', 'ARTE', 'BBC Film', 'TRT', 'Turkish Radio & Television', 'Bord Cadre Films', 'Coproduction Office', 'Film i Väst', 'Heretic', 'Imperative Entertainment', 'Piano', 'Sovereign Films', 'Plattform Produktion', 'SVT', 'Svensk Filminspelning', 'Essential Films', 'ZDF', 'Svenska Filminstitutet', 'Eurimages', 'Medienboard Berlin-Brandenburg', 'The Danish Film Institute', 'Canal+', 'Ciné+', 'DR', 'Nordisk Film & TV Fond', 'BFI', 'MOIN Filmförderung Hamburg Schleswig-Holstein', 'SF Studios', 'Bac Films', 'Curzon Film World']
# ['20th Century Fox', 'Blue Sky Studios', '20th Century Fox Animation']
# ['Warner Bros. Japan', 'Oxybot']
# ['Flynn Picture Company', 'Seven Bucks Productions', 'Bad Version']
# ['New Line Cinema', 'Village Roadshow Pictures', 'Flynn Picture Company', 'Warner Bros. Pictures']
# ['Evergreen Media Group', 'New Line Cinema', 'The Safran Company']
# ['Summit Entertainment', 'Temple Hill Entertainment', 'Maverick Films', 'Imprint Entertainment', 'Goldcrest', 'Twilight Productions']
# ['Davis Entertainment', 'Laurence Mark Productions', 'Canlaws Productions', '20th Century Fox', 'Overbrook Entertainment', 'Mediastream Vierte Film GmbH & Co. Vermarktungs KG']
# ['Maximum Effort', 'Genre Films', '20th Century Fox']
# ['Amazon Studios', 'Skydance Sports', 'Mandalay Pictures', 'Artists Equity']
# ['Jerry Bruckheimer Films', 'Second Mate Productions', 'Walt Disney Pictures']
# ['Nu Boyana Viburno']
# ['Miramax', 'Metro-Goldwyn-Mayer', 'Toff Guy Films', 'Flic Films UK']
# ['Toei Company', 'Entertainment One']
# ['Studio Deen', 'VIZ Media']
# ['Gold Circle Films', 'Focus Features']
# ['Gentosha']
# ['One Cool Film Production', 'Media Asia Films', 'World Universal Culture Limited', 'iQIYI Pictures', 'Tianjin Maoyan Media', 'CMC Pictures', 'Shenzhen Film Studio']
# ['HCT Media']
# ['Marv Films', 'Cloudy Productions', '20th Century Studios']
# ['Asturiana de Films', 'BH5', 'Tiki Pictures']
# ['Paramount', 'Entertainment One', 'Kerner Entertainment Company', 'Scholastic Entertainment', 'New Republic Pictures', 'Walden Media']
# ['Pokeepsie Films', 'Telecinco Cinema', 'Mediaset España', 'Movistar+']
# ['Second Grade Teacher Productions', 'Blumhouse Productions', 'Momentum Pictures']
# ['Paramount', 'Platinum Dunes']
# ['Fox 2000 Pictures', 'Levantine Films', 'Chernin Entertainment']
# ['Mobra Films', 'Why Not Productions', 'France 3 Cinéma', 'Les Films du Fleuve', 'Filmgate Films', 'Film iVäst']
# ['Les Éditions Albert René', 'Les Enfants Terribles', 'Pathé', 'Trésor Films']
# ['Paramount', 'di Bonaventura Pictures', 'Ian Bryce Productions', 'Tom DeSanto/Don Murphy Production']
# ['Warner Bros. Pictures', 'Nick Wechsler Productions', 'Free Association']
# ['The Film Department', 'Evil Twins', 'Warp Films', 'G-BASE', 'Overture Films']
# ['Chernin Entertainment', 'about:blank']
# ['Columbia Pictures', 'QED International', 'LStar Capital', 'Le Grisbi Productions', 'Crave Films', 'Sony Pictures', 'Huayi Brothers Pictures']
# ['Toei Company', 'Bird Studios', 'Toei Animation']
# ['Marvel Enterprises', 'Laura Ziskin Productions']
# ['Diagonal Pictures']
# ['Columbia Pictures', 'Sony Pictures', 'Happy Madison Productions']
# ['ANDMARQ Studio']
# ['Savoy Pictures', 'HBO Films']
# ['Marvel Entertainment', 'Laura Ziskin Productions', 'Columbia Pictures', 'Matt Tolmach Productions', 'Avi Arad Productions']
# ['Dimension Films', 'The Weinstein Company', 'Outerbanks Entertainment']
# ['Marvel Studios', 'Pascal Pictures', 'LStar Capital']
# ['Daniel Stisen Productions', 'Fansu Film']
# ['Basque Films', 'Mr. Miyagi', 'EiTB', 'RTVE']
# ['Daybreak Productions', 'Prime Universe Productions', 'Giant Pictures', 'TSG Entertainment', 'Dayday Films', 'Ingenious Media', 'Fox International Productions', 'Deutscher Filmförderfonds', '20th Century Fox', 'Medienboard Berlin-Brandenburg']
# ['AGADIC', 'Fasten Films', 'ICAA', 'OlloVivo Producións', 'Xunta de Galicia', 'RTVE', 'Cinemate']
# ['Idea(L)', 'Vocab Films', 'New Sparta Films', 'Ingenious Media', 'Lipsync Productions', 'Cornerstone Films']
# ['Studio Ghibli']
# ['Studio Deen', 'VIZ Media', 'Kitty Films']
# ['Mattel Television', 'Brightlight Pictures', 'Nickelodeon Productions', 'Lighthouse Pictures']
# ['AGBO', 'Roth-Kirschenbaum Films', 'Stillking Films', 'Brazil Production Services']
# ['AGBO', 'Ley Line Entertainment', 'Year of the Rat Productions', 'Hotdog Hands LLC', 'A24', 'IAC Films']
# ['Wild Spark', 'Bigscope Films', "Don't Hang Up Films"]
# ['BondIt Media Capital', 'Lionsgate', 'Renegade Entertainment']
# ['Bad Robot']
# ['Tubi TV', 'The Exchange', 'Arcana Productions']
# ['Castle Rock Entertainment']
# ['Marvel Studios', 'Luma Pictures']
# ['Walt Disney Pictures', 'Bardel Entertainment', '20th Century Studios']
# ['Spin Master', 'Nickelodeon Movies', 'Paramount', 'Mikros Image', 'Elevation Pictures']
# ['DreamWorks Animation', 'Paramount']
# ['Miramax', 'Lawrence Bender Productions', 'Be Gentlemen Limited Partnership']
# ['Twisted Media', 'Skydance Media', 'RatPac Entertainment', 'Electric Entertainment', 'Warner Bros. Pictures', 'October Pictures']
# ['CAPCOM', 'Constantin Film', 'Impact Pictures', 'Tencent Pictures', 'TOHO']
# ['Tim Burton Productions', 'Skellington Productions Inc.', 'Touchstone Pictures', 'Walt Disney Pictures']
# ['Excellent Cadaver', 'Sony Pictures', 'Odenkirk Provissiero Entertainment']
# ['Konrad Pictures', 'Dimension Films', 'Craven-Maddalena Films']
# ['Columbia Pictures', 'Bron Studios', 'The Montecito Picture Company', 'Ghost Corps']
# ['DreamWorks Animation', 'Pacific Data Images', 'Paramount']
# ['H2L Media Group', 'Rhea Films']
# ['Machaco Films']
# ['Trompetero Producciones', 'Cinecolor Films']
# ['Warner Bros. Pictures', 'WingNut Films', 'New Line Cinema', '3Foot7', 'Metro-Goldwyn-Mayer']
# ['Universal Pictures', 'Blumhouse Productions', 'Miramax', 'Rough House Pictures', 'Trancas International Films']
# ['Walt Disney Pictures', 'Jerry Bruckheimer Films', 'Second Mate Productions']
# ['The Solution', 'Zero Gravity Management', 'Film Victoria', 'Lightstream Entertainment', 'Screen Australia']
# ['Pure Imagination Studios', 'LEGO', 'Marvel Entertainment']
# ['Lionsgate', 'Relativity Media', 'Sighvatsson Films', 'Michael De Luca Productions', 'Palomar Pictures']
# ['Toei Animation', 'Shueisha', 'Toei Company', 'Fuji Television Network', 'Bandai', 'Bandai Namco Entertainment', 'ADK Emotions', 'dentsu']
# ['Walt Disney Pictures']
# ['RatPac Entertainment', 'Village Roadshow Pictures', '22 & Indiana Pictures', 'Malpaso Productions', 'Warner Bros. Pictures', 'Mad Chance']
# ['TMS Entertainment']
# ['DC Comics', 'Legendary Pictures', 'Syncopy', 'Isobel Griffiths', 'Warner Bros. Pictures']
# ['Imagenation Abu Dhabi FZ', 'Lost City', 'Spooky Pictures', 'AGC Studios']
# ['Studio Ghibli', 'dentsu Music And Entertainment', 'Mitsubishi', 'Nippon Television Network Corporation', 'Tohokushinsha Film Corporation', 'Tokuma Shoten', 'd-rights', 'Walt Disney Pictures']
# ['Yellow, Black & White', 'The Walt Disney Company CIS', 'Cinema Fund', 'Russia-1']
# ['Zeta Studios']
# ['Zagtoon', 'Method Animation', 'Toei Animation', 'SAMG Animation', 'Norman Studio Works', 'The Walt Disney Company France', 'TF1', 'Mediawan', 'Télé-Québec', 'Fantawild Animation', 'Gloob']
# ['Film Bridge International', 'Paper Street Pictures', 'Saban Films']
# ['Saturn Films', 'Burr! Productions']
# ['Warner Animation Group', 'SpringHill Entertainment', 'Proximity Media', 'Warner Bros. Pictures']
# ['Warner Bros. Animation', 'Hanna-Barbera Productions']
# ['Undisputed 3 Productions', 'Nu Image']
# ['BondIt Media Capital', 'Buffalo 8 Productions', 'Lucky 13 Productions']
# ['Deluca Film']
# ['The Asylum', 'The Global Asylum, LLC.']
# ['Apelles Entertainment', 'Gravity Pictures', 'di Bonaventura Pictures', 'Flagship Entertainment Group', 'Maeday Productions', 'Warner Bros. Pictures']
# ['Hoya Productions', 'Warner Bros. Pictures']
# ['87North Productions', 'Odenkirk Provissiero Entertainment', 'Eighty Two Films']
# ['Columbia Pictures', 'Relativity Media', 'Sony Pictures', 'Happy Madison Productions']
# ['Gaumont', 'Amazon Studios']
# ['Non-Stop Productions', 'DK Entertainment', 'Central Partnership', 'KIT Film Studio']
# ['Legendary Pictures', 'Green Hat Films', 'Warner Bros. Pictures']
# ['GoHands', 'Glovision', 'THE KLOCKWORX', 'King Records']
# ['See-Saw Films', 'Porchlight Films', 'Universal Pictures International Production (UPIP)', 'Film4 Productions', 'Focus Features']
# ['Ay Yapım']
# ['Brad Grey Pictures', 'Gold/Miller Productions', 'Wayans Bros. Entertainment', 'Dimension Films']
# ['Ghost House Pictures', 'Screen Gems']
# ['87Eleven', 'Impossible Dream Entertainment']
# ['Amblin Entertainment', 'De Line Pictures', 'Warner Bros. Pictures', 'Dune Entertainment', 'Farah Films & Management', 'Reliance Entertainment', 'Village Roadshow Pictures']
# ['Monkeypaw Productions', 'Blumhouse Productions', 'QC Entertainment']
# ['Walt Disney Pictures', 'Seven Bucks Productions', 'Davis Entertainment', 'Flynn Picture Company', 'TSG Entertainment', 'Zaftig Films']
# ['Allfilm', 'Sentinel Entertainment', 'Kick Film', 'CrossDay Productions', 'Stigma Films', 'Tallifornia']
# ['Hyperobject Industries', 'Searchlight Pictures', 'Gary Sanchez Productions', 'TSG Entertainment']
# ['Walt Disney Pictures', 'Depth of Field', 'ImageMovers']
# ['GK Films', 'Paramount', 'Hemisphere Media Capital', '2DUX²', 'Apparatus Productions', 'Latina Pictures', 'Skydance Media', 'Plan B Entertainment']
# ['20th Century Studios', 'Original Film']
# ['Double Dare You Productions', 'Legendary Pictures']
# ['20th Century Fox', 'Marv Films', 'Cloudy Productions', 'TSG Entertainment']
# ['BBC']
# ['Rosebud Releasing Corporation', 'Renaissance Pictures', 'Dino De Laurentiis Company']
# ['Craven-Maddalena Films', 'Dimension Films', 'Konrad Pictures']
# ['Warner Bros. Pictures', 'The Stone Quarry', 'DC Films', 'Atlas Entertainment']
# ['Sight Unseen Pictures', 'Makeready', 'Hillman Grad Productions']
# ['Moho Film', 'CJ Entertainment']
# ['Warner Bros. Pictures', 'The Safran Company', 'DC Films']
# ['Summit Entertainment', 'Temple Hill Entertainment', 'Imprint Entertainment', 'Maverick Films', 'Sunswept Entertainment']
# ['Amblin Entertainment', 'ImageMovers', 'Misher Films', 'Reliance Entertainment']
# ['Caper Film']
# ['Screen Savers Entertainment']
# ['Walt Disney Pictures', 'China Film Group Corporation', 'Good Fear', 'Jason T. Reed Productions']
# ['Skydance Media', 'Maximum Effort', '21 Laps Entertainment']
# ['Legendary Pictures', 'Huahua Media', 'TOHO']
# ['Walt Disney Pictures', 'Fairview Entertainment']
# ['Warner Bros. Pictures', 'RatPac Entertainment', 'DC Comics', 'Atlas Entertainment', 'Cruel & Unusual Films', 'DC Entertainment']
# ['Zagtoon', 'Method Animation', 'SAMG Animation', 'Norman Studio Works', 'The Walt Disney Company France', 'TF1', 'Gloob', 'Télé-Québec', 'Fantawild Animation', 'Mediawan']
# ['New Line Cinema', 'WingNut Films', 'The Saul Zaentz Company']
# ['Walt Disney Productions']
# ['Eon Productions', 'Metro-Goldwyn-Mayer', 'Universal Pictures']
# ['M.M.D. Rome']
# ['20th Century Studios', 'Flitcraft']
# ['Universal Pictures', 'Perfect World Pictures', 'Michael De Luca Productions', 'dentsu', 'Fuji Television Network', 'Perfect World Pictures']
# ['Flying Tigers Entertainment', 'Aniventure', 'HB Wink Animation', 'Cinesite Animation', 'Align', 'GFM Animation', 'Nickelodeon Movies', 'Brooksfilms Ltd.', 'Mass Animation', 'Blazing Productions']
# ['Universal Pictures']
# ['BONES', 'Bandai Namco Arts', 'Bandai Namco Sevens', 'Hakuhodo DY Music & Pictures', 'Sammy', 'MBS']
# ['di Bonaventura Pictures', 'Closest to the Hole Productions', 'Leverage Entertainment', 'Paramount', 'New Republic Pictures']
# ['Bandai Namco Games', 'Toei Animation', 'Fuji Television Network', 'Shueisha', 'Fox International Productions', 'Toei Company', 'Bandai Visual', '20th Century Fox', '20th Century Fox Animation']
# ['Aniplex']
# ['United Plankton Pictures', 'Nickelodeon Movies', 'Paramount Animation', 'Paramount', 'MRC', 'Mikros Image']
# ['Gulfstream Pictures', 'Happy Madison Productions', 'RatPac Entertainment']
# ['Lucky Star (H.K.) Film Co.', 'Filmline Enterprises']
# ['Columbia Pictures', 'Centropolis Entertainment', 'Farewell Productions', 'The Mark Gordon Company']
# ['Rox Productions', 'Revolution Studios', 'Maple Cage Productions', 'Huahua Media', 'Roth-Kirschenbaum Films', 'Shanghai Film Group', 'One Race', 'Paramount']
# ['Eyeworks', 'Vlaams Audiovisueel Fonds', 'Screen Flanders', 'Kinepolis Film Productions', 'Les Films du Fleuve', 'Phanta Film', 'Atlas International Film', 'screen.brussels']
# ['Yale Productions', 'BondIt Media Capital', 'Buffalo 8 Productions']
# ['Nostromo Pictures']
# ['RainMaker Films', 'Yale Productions', 'The Machine Room', 'Post Film']
# ['Legendary Pictures', 'Syncopy', 'Warner Bros. Pictures']
# ['Madhouse', 'KADOKAWA']
# ['Paper Street Pictures', 'Last Resort Ideas', 'Blood Oath']
# ['Zip Cinema', 'CJ ENM']
# ['Seven']
# ['Apeitda']
# ['BONES', 'TOHO', 'Yomiuri Telecasting Corporation', 'Shueisha', 'Nippon Television Network Corporation', 'dentsu', 'Sony Music Entertainment (Japan)', 'movic']
# ['New Line Cinema', 'Dune Entertainment', 'The Safran Company', 'Evergreen Media Group', 'Atomic Monster']
# ['The Zanuck Company', 'Theobald Film Productions', 'Plan B Entertainment']
# ['DisneyToon Studios']
# ['New Line Cinema', 'Atomic Monster', 'The Safran Company']
# ['Smart Entertainment', 'Universal Pictures', 'Fuzzy Door Productions', 'Bluegrass Films', 'MRC']
# ['Peppermint&company', 'Next Entertainment World', 'Studio & New', 'Goldmoon Film', 'Contents Panda', 'Warner Bros. Korea']
# ['Lonetree Entertainment', 'Fuqua Films', 'Escape Artists', 'Sony Pictures', 'ZHIV Productions', 'Mace Neufeld Productions', 'Columbia Pictures']
# ['Warner Bros. Animation', 'DC Entertainment']
# ['Ka Shing Film Production Co.']
# ['Landline Pictures', 'Levantine Films', 'Paramount Players', 'Netter Productions']
# ['Causeway Films', 'Head Gear Films', 'Metrol Technology']
# ['Warner Bros. Animation']
# ['Atomic Monster', 'The Safran Company', 'New Line Cinema']
# ['Dark Age Cinema']
# ['TSG Entertainment', 'Chernin Entertainment', 'Ingenious Media']
# ['Grafi2000 Productions']
# ['Marvel Studios', 'Pascal Pictures']
# ['Universal Pictures', 'Alphaville Films']
# ['Walt Disney Pictures', 'Jerry Bruckheimer Films', 'Infinitum Nihil']
# ['Tim Burton Productions', 'Laika Entertainment', 'Patalex Productions', 'Warner Bros. Pictures', 'Will Vinton Studios', 'Tim Burton Animation Company']
# ['GoHands']
# ['Metro-Goldwyn-Mayer', 'Bron Studios', 'BermanBraun', 'Cinesite Animation', 'Nitrogen Studios Canada']
# ['Skydance Media', 'Paramount', 'Annapurna Pictures']
# ['Walt Disney Pictures', 'Mandeville Films']
# ['Acajou Films', 'Rebel Rebel', 'Birka Holding']
# ['Thunder Road', '30WEST', 'STX Entertainment', 'Ingenious Media', 'Paramount']
# ['MarVista Entertainment', 'Brightlight Pictures']
# ['Blue Sky Studios', '20th Century Fox Animation', '20th Century Fox']
# ['Hello Sunshine', 'Aggregate Films', 'Lean Machine']
# ['Summit Entertainment', 'Netter Productions']
# ['Instituto Mexicano de Cinematografía', 'Bandidos Films', 'Estudios Churubusco Azteca']
# ['Latido Films', 'Aeroplano Cine', 'Mother Superior']
# ['Paramount', 'Don Simpson/Jerry Bruckheimer Films']
# ['Pulse Films', 'Warner Horizon Unscripted & Alternative Television', 'Casey Patterson Entertainment']
# ['Wrigley Pictures', 'New Line Cinema', '7 Bucks Entertainment', 'ASAP Entertainment', 'Flynn Picture Company', 'Twisted Media']
# ['La Soga Producciones', 'BF Distribution']
# ['Weed Road Pictures', 'Outlier Society Productions', 'The Saw Mill']
# ['Park Pictures Features', 'Revelations Entertainment', 'The Exchange', 'Anonymous Content']
# ['Nickelodeon Movies', 'Paramount', 'Platinum Dunes', 'Mirage Studios']
# ['Motion Picture Corporation of America', 'Brad Krevoy Television', 'Lighthouse Pictures']
# ['DreamWorks Animation', 'DreamWorks Pictures']
# ['All Canadian Entertainment', 'Motion Picture Corporation of America', 'Brad Krevoy Television']
# ['Azmun Films']
# ['FLAT STUDIO', 'avex pictures']
# ['Torridon Films', '16:14 Entertainment', 'Scott Free Productions', 'Columbia Pictures', 'Alcon Entertainment', 'Thunderbird Entertainment', 'Warner Bros. Pictures']
# ['Night Train Media', 'Great Point Media', 'Split Prism Media', 'Ahinga Media', 'Rabbit Track Pictures']
# ['Avnet/Kerner Productions', 'Metro-Goldwyn-Mayer']
# ['Monkey Movies', 'Moonshine Animation', 'Kaohsiung Film Fund']
# ['20th Century Fox', 'Summit Entertainment', 'Constantin Film']
# ['Pearl Studio', 'DreamWorks Animation', 'China Film Group Corporation', '20th Century Fox']
# ['Matt Tolmach Productions', 'Pascal Pictures', 'Marvel Entertainment', 'Tencent Pictures', 'Avi Arad Productions']
# ['Castle Rock Entertainment', 'Darkwoods Productions', 'Warner Bros. Pictures']
# ['C-JeS Entertainment', 'MAGNUM9', 'Cine Joo', 'Dexter Studios']
# ['Don Films']
# ['Illumination', 'Universal Pictures', 'Fuji Television Network', 'dentsu']
# ['F.G. Film Productions']
# ['DreamWorks Animation', 'Pacific Data Images', '20th Century Fox']
# ['BBC Film', 'Miramax', 'Heyday Films']
# ['Icon Entertainment International', 'Icon Productions', 'Touchstone Pictures']
# ['DisneyToon Studios', 'Prana Animation Studios']
# ['Jagged Edge Productions']
# ['GapBusters', 'A Single Man Productions']
# ['The Mark Gordon Company', 'Vendôme Pictures', 'Summit Entertainment', 'StudioCanal', "Mel's Cite du Cinema"]
# ['Warner Bros. Pictures', 'Metro-Goldwyn-Mayer', 'New Line Cinema', 'WingNut Films']
# ['Anton', 'Stigma Films']
# ['Done+Dusted']
# ['Highland Film Group', 'Bay Point Media', '23ten', 'Particular Crowd', 'Streamline Global', 'Thomasville Pictures', 'Ignition Film Productions', 'Source Management + Production', 'Short Porch Pictures', 'Baird Film']
# ['Bazmark Films', 'The Jackal Group', 'Warner Bros. Pictures', 'Fin Design & Effects']
# ['Summit Entertainment', 'Escape Artists', 'Mystery Clock Cinema', 'Kaplan/Perrone Entertainment', 'Wintergreen Productions', 'Goldcrest']
# ['Village Roadshow Pictures', 'Lonely Film Productions GmbH & Co. KG.', "The Donners' Company", 'Batfilm Productions', 'Weed Road Pictures', 'Warner Bros. Pictures', '3 Arts Entertainment', 'DC Vertigo']
# ['Orient 21']
# ['Constantin Film', 'Summit Entertainment']
# ['DreamWorks Animation', 'Mad Hatter Entertainment', 'Vertigo Entertainment', '20th Century Fox']
# ['Timeless Films', 'Axis Studios']
# ['Columbia Pictures', 'Seven Bucks Productions', 'Matt Tolmach Productions', 'The Detective Agency']
# ['Elite Film']
# ['Walt Disney Pictures', 'Genre Films', 'Beagle Pug Films', 'Allison Shearmur Productions']
# ['Air Street Films', 'The Bureau']
# ['STX Entertainment']
# ['Causeway Films']
# ['Lotte Entertainment', 'Big Stone Pictures']
# ['Big Screen Productions', 'Chernin Entertainment', 'Tim Burton Productions', 'SCOPE Pictures', 'TSG Entertainment', 'Ingenious Media', '20th Century Fox', 'St. Petersburg Clearwater Film Commision']
# ['Walt Disney Pictures', 'Edgar Rice Burroughs Inc.', 'Walt Disney Feature Animation']
# ['EuropaCorp', 'Grive Productions', 'M6', 'TSG Entertainment', '20th Century Fox', 'Fox International Productions', 'Canal+', 'Ciné+']
# ['Steven Paul Production', 'Wonder Street', 'Front Street Pictures']
# ['Chernin Entertainment', 'BBC Film', 'BBC Studios']
# ['Creativ Studios', 'High Fliers Films']
# ['Village Roadshow Pictures', 'Groucho II Film Partnership', 'Silver Pictures', 'Warner Bros. Pictures']
# ['Light Chaser Animation Studios', 'The Weinstein Company', 'Alibaba Pictures Group']
# ['Penthouse Films International', 'Felix Cinematorgrafica']
# ['Escape Artists', 'LStar Capital', 'MRC', 'Sony Pictures']
# ['Miramax', 'A Band Apart', 'Jersey Films']
# ['Traziende Films']
# ['Lucasfilm Ltd.', 'Bad Robot']
# ['1492 Pictures', 'Sunswept Entertainment', 'Dune Entertainment']
# ['Trailer Films', 'La Expresión del Deseo']
# ['Regency Enterprises', 'Fox 2000 Pictures', 'Taurus Film', 'Atman Entertainment', 'Knickerbocker Films', 'The Linson Company', '20th Century Fox']
# ['Barunson E&A']
# ['Acemaker Movieworks', 'BA Entertainment', 'Kiwi Media Group', 'B&C CONTENT']
# ['Paramount', 'Amblin Entertainment', 'Cruise/Wagner Productions', 'DreamWorks Pictures']
# ['Legendary Pictures', 'Bad Hombre Films', 'Exurbia Films', 'Good Universe']
# ['Cine Latino']
# ['Warner Bros. Animation', 'Blue Ribbon Content', 'Berlanti Productions', 'DC Entertainment']
# ['Level 33 Entertainment']
# ['A24', 'Square Peg', 'IPR.VC', 'Access Entertainment']
# ['Summit Entertainment', 'Temple Hill Entertainment', 'Sunswept Entertainment', 'Lionsgate']
# ['20th Century Fox', 'Marv Films', 'Cloudy Productions', 'TSG Entertainment', 'Shangri-La Entertainment']
# ['Storyteller Studios', 'Reel One Entertainment', 'Lifetime']
# ['RatPac Entertainment', 'Cruel & Unusual Films', 'Atlas Entertainment', 'Warner Bros. Pictures', 'DC Films']
# ['New Line Cinema', 'Vertigo Entertainment', 'Double Dream', 'Rideback']
# ['Tsuburaya Productions', 'TOHO', 'khara', 'Cine Bazar']
# ['Syncopy', 'Legendary Pictures', 'DC Entertainment', 'Warner Bros. Pictures']
# ['Shueisha', 'Gallop', 'TV Tokyo', 'NAS', '4Kids Entertainment']
# ['Blinder Films', 'Sigma Films Ltd.', 'Screen Ireland']
# ['STX Entertainment', 'Toff Guy Films']
# ['ImageMovers', 'Warner Bros. Pictures', 'Double Dare You Productions', 'Necropia Entertainment', 'Esperanto Filmoj']
# ['Dimension Films', 'The Weinstein Company', 'Brad Grey Pictures']
# ['Universal Pictures', 'Bay Films', 'Endeavor Content', 'New Republic Pictures', 'Project X Entertainment']
# ['Warner Bros. Japan', 'Amuse Soft Entertainment']
# ['Overbrook Entertainment']
# ['New Line Cinema', 'Island Pictures']
# ['Lucasfilm Ltd.']
# ['Blumhouse Productions', 'Platinum Dunes', 'Universal Pictures', 'Perfect World Pictures', 'Man in A Tree']
# ['Scott Rudin Productions', 'Orion Pictures', 'Paramount']
# ['Universal Pictures', 'Amblin Entertainment']
# ['China Film Group Corporation', 'Beijing Jingxi Culture', 'Beijing Dengfeng International Culture', 'G!Film Studio', 'Free Whale Pictures']
# ['Lionsgate', 'Color Force', 'Studio Babelsberg', 'Seashore GER 1']
# ['DNA Films', 'A24']
# ['Pierrot', 'Studio Lagurus', 'Aniplex', 'Bandai Namco Entertainment', 'Bandai', 'dentsu', 'Shueisha', 'TV Tokyo', 'TOHO']
# ['Ghost House Pictures', 'Stage 6 Films', 'Good Universe', 'Bad Hombre Films', 'Screen Gems']
# ['Gracie Films', 'Film Roman', '20th Century Fox Animation', 'The Curiosity Company', '20th Century Fox']
# ['Warner Bros. Pictures', 'Joint Effort', 'Village Roadshow Pictures', 'Bron Studios', 'DC Films']
# ['IM Global', 'Impostor Pictures', '42']
# ['Walt Disney Pictures', 'Roth Films']
# ['LuckyChap Entertainment', 'Heyday Films', 'Warner Bros. Pictures', 'Mattel']
# ['Fox 2000 Pictures', 'Dune Entertainment', 'Major Studio Partners', 'Peninsula Films']
# ['Silver Pictures', 'Green Hat Films']
# ['Lionsgate', 'Saban Brands', 'Saban Films', 'Temple Hill Entertainment', 'TIK Films']
# ['Jigsaw Productions']
# ['Universal Pictures', 'Will Packer Productions', 'The Story Company']
# ['Constantin Film', 'The H Collective', 'Tea Shop & Film Company', 'Lionsgate']
# ['M-Line Distribution', 'iHQ']
# ['Disney Television Animation', 'DisneyToon Studios', 'Walt Disney Pictures']
# ['New Line Cinema', 'Vertigo Entertainment', 'Lin Pictures', 'KatzSmith Productions']
# ['GDH 559', 'Northern Cross', 'Jorkwang Films', 'Showbox', 'Finecut']
# ['Warner Animation Group', 'Turner Entertainment', 'The Story Company', 'Warner Bros. Pictures']
# ['dentsu', 'Aniplex', 'Shueisha', 'TV Tokyo', 'Pierrot', 'TOHO', 'Bandai Visual']
# ['Lightstorm Entertainment', 'Skydance Media', '20th Century Fox', 'Paramount', 'Tencent Pictures', 'TSG Entertainment', 'Ministry of Finance of Spain', 'Ministerio de Cultura', 'Hungarian National Film Fund', 'Mid Atlantic Films']
# ['FilmNation Entertainment', 'Kennedy Miller Productions', 'Metro-Goldwyn-Mayer', 'Elevate Production Finance', 'CAA Media Finance', 'Sunac Pictures']
# ['MGA Entertainment']
# ['Regency Enterprises', 'Forward Pass', 'Warner Bros. Pictures', 'New Regency Productions', 'The Linson Company', 'Monarchy Enterprises B.V.']
# ['Destination Films']
# ['See Pictures']
# ['Walden Media', 'New Line Cinema', 'Contrafilm']
# ['La Maison de Prod']
# ['Escape Artists', 'Sony Pictures', 'Bron Studios']
# ['Summit Entertainment', 'Sunswept Entertainment', 'TSBD Canada Productions', 'TSBD Louisiana', 'TSBD Productions', 'Temple Hill Entertainment', 'Total Entertainment']
# ['Les Bookmakers', 'The Jokers']
# ['Next Entertainment World', 'RedPeter Film', 'Contents Panda', 'Union Investment Partners', 'KTB Network', 'Korean Film Council']
# ['Bibury Animation Studios']
# ['China Film Group Corporation', 'Guo Fan Culture and Media']
# ['Paramount', 'Metro-Goldwyn-Mayer', 'di Bonaventura Pictures', 'Entertainment One', 'Skydance Media', 'Hasbro']
# ['Warner Bros. Pictures', 'New Line Cinema', 'Starlight International Media', 'Midas Innovation', 'Atomic Monster', 'BOOM! Studios']
# ['Illumination', 'Universal Pictures']
# ['Skydance Media', 'Huahua Media', 'Shanghai Film Group', 'TC Productions', 'Paramount']
# ['Rapi Films', 'Sky Media']
# ['Legendary Pictures', 'The Pokémon Company']
# ['Nexus Studios']
# ['Legendary Pictures', 'Double Dare You Productions']
# ['Brandywine Productions', '20th Century Fox']
# ['Studio 100 Media', 'Studio 100', 'Studio B Animation', 'Constantin Film']
# ['Wallaz Producciones']
# ['Silver Pictures', '20th Century Fox', 'Lawrence Gordon Productions', 'Davis Entertainment', 'Amercent Films', 'American Entertainment Partners L.P.', 'Estudios Churubusco Azteca S.A.']
# ['Nu Image', 'Lionsgate', 'EFO Films', 'Equity Pictures Medienfonds GmbH & Co. KG IV', 'Millennium Films']
# ['Focus Features', 'FilmNation Entertainment', 'Unified Theory Productions', 'Scoop Productions']
# ...
# ['Suretone Pictures', 'Mimran Schur Pictures']
# ['Universal Pictures', 'Team Todd', 'Prime Film Productions LLC', 'Younger Than You']
# ["N' Credible Entertainment"]
# ['France 2 Cinéma', 'SBS Productions', 'Twenty Twenty Vision Filmproduktion', 'Proximus', 'Entre Chien et Loup']
# ['Vendian Entertainment', 'Larger Than Life Productions', 'STX Entertainment', 'Bluegrass Films', 'Rahway Road Productions', 'Huayi Brothers Pictures', 'IM Global', 'Route One Entertainment', 'Union Investment Partners']
# ['Anonymous Content', 'Treehouse Pictures']
# ['BFI', 'Screen Yorkshire', 'Creative Scotland', 'Warp Films', 'Crab Apple Films', 'Film4 Productions']
# ['Di Novi Pictures']
# ['United Artists', 'Omni Zoetrope Studios']
# ['Shueisha', 'Tokyo Movie Shinsha']
# ['Rapid Film']
# ['Wild Bunch', 'La Classe américaine', 'Getaway Films', 'BlueLight', 'Pan-Européenne', 'ENBU Seminar', 'GAGA Corporation', 'France 2 Cinéma', 'Ivanhoe Pictures', 'Sidney Kimmel Entertainment']
# ['Avalon', 'Vilaüt Films', 'Kino Produzioni']
# ['Fresh Bread', 'Pulse Films', 'PolyGram Filmed Entertainment', 'Oscilloscope']
# ['MTV Films']
# ['Sesame Workshop']
# ['Miscellaneous Entertainment', 'StarStream Media', 'Rookfield Productions', 'WWKG Productions', 'Folktale Productions', 'Ingenious Media', 'Rowdy Row Productions', 'RuYi Media']
# ['Quickfire Films', 'Sigma Films Ltd.', 'Lipsync Productions', 'Film4 Productions', 'Creative Scotland', 'Northern Ireland Screen']
# ['Jadran Film', 'Rialto Film Preben-Philipsen']
# ['Twin Engine Films', 'Pink Buffalo Films', 'Abduction Films', 'Manis Film', 'Vicarious Entertainment']
# ['Artisan Entertainment', 'CTV International']
# ['Warner Independent Pictures (WIP)', 'NALA Films', 'Summit Entertainment', 'Samuels Media', 'Blackfriars Bridge Films']
# ['Shaken, Not Stirred Productions', 'Balkanic Media', 'Legendary Pictures', 'Uh Hundred Percent', 'Levity Productions', 'Screen Gems']
# ['Art Top Movie Productions', "Jing's Production Limited"]
# ['Scott Rudin Productions', 'RT Features', 'Pine District Pictures']
# ['Tycor International Film Company', 'MarVista Entertainment']
# ['New Sparta Films', 'S Films']
# ['RAI']
# ['BCDF Pictures', 'Baral Waley Productions', 'Shaken, Not Stirred Productions', 'Bluewater Lane Productions']
# ['Fortitude International', 'Eyeworks Scandi Fiction', 'Creative Alliance']
# ['Miramax', 'Universal Pictures', 'Working Title Films', 'Atlantic Television', 'StudioCanal', 'Little Bird']
# ['Castle Rock Entertainment', 'ASIG Productions', 'Envision Entertainment']
# ['Marvel Animation', 'MLG Productions 4']
# ['Avventurosa', 'IBC MOvie', 'The Match Factory', 'Shellac Sud', 'ARTE', 'BR', 'RAI Cinema']
# ['Jerry Media', 'Library Films', 'VICE Media']
# ['Curzon Film Distributors', 'Goldcrest', 'National Film Finance Corporation (NFFC)']
# ['Canal+ Polska', 'ZDF', 'Slot Machine', 'Zentropa International Köln', 'Zentropa International France', 'Liberator Productions', 'Shot - Szumowski']
# ['Sony Pictures Home Entertainment', 'Stage 6 Films']
# ['Dimension Films', 'Gatlin Films']
# ['Pindrop', 'Kriti Productions', 'Fugitive Studios', 'HireWorks', 'Lipsync Productions']
# ['Take 1 Productions']
# ['Mars Production Pty. Ltd.', 'Village Roadshow Pictures', 'NPV Entertainment', 'The Canton Company', 'Warner Bros. Pictures']
# ['UFO Pictures', 'Scotty Gelt', 'BondIt']
# ['Paramount', 'MTV Films']
# ['The Levinson/Fontana Company', 'Pressman Film', 'HBO Films']
# ['Dog Pond Productions', 'Yan Film Group', 'Paris Film', 'Revelations Entertainment']
# ['Chazown Pictures', 'Paramount', 'Disruption Entertainment']
# ['TriStar Pictures', 'Crescent Film Enterprises']
# ['H2O Films', 'PinGuim Content']
# ['Sola Digital Arts', 'Sony Pictures']
# ['Knickerbockerglory TV']
# ['Castle Rock Entertainment', 'Wildwood Enterprises']
# ['Moon River Studios', 'Aloe Entertainment', 'Lionsgate']
# ['Sanai Pictures', 'Peppermint&company', 'Daemyung Culture Factory', 'Next Entertainment World', 'kth', 'Finecut']
# ['Mediapro', 'Televisión Abierta']
# ['Terror Films']
# ['Lambart Productions', 'TF1 Films Production', 'CNC', 'Investimage 2', 'Investimage 3']
# ['Regency Enterprises', 'New Regency Pictures', 'Vertigo Entertainment', 'Ozla Pictures']
# ['Sidus', 'Little Big Pictures', 'Union Investment Partners']
# ['Pathé', 'Lipsync Productions', 'Master Movies', 'FilmWave', 'WS Film', 'Canal+', 'X Filme Creative Pool', 'Buffalo Films']
# ['WY Productions', 'Mars Films', 'R.P. Productions', 'France 2 Cinéma', 'Monolith Films', 'Belga Productions', 'Cofinova 13', 'Cinéventure 2', 'Canal+', 'Ciné+', 'France Télévisions', 'PISF']
# ['Erma-Film']
# ['The Orchard', 'Duplass Brothers Productions']
# ['Lionsgate', 'Jorva Entertainment Productions', 'Codeblack Films', 'Flavor Unit Entertainment']
# ['Endymion Films', 'ScreenWest', 'Woss Group Film Productions', 'Screen Australia', 'Essential Entertainment', 'South Australian Film Corporation']
# ['Gimages 3', 'CNC', 'ARTE France Cinéma']
# ['Beacon Communications', 'Touchstone Pictures', 'Beacon Pictures', 'Casey Silver Productions', 'Fantail Films Inc.']
# ['Babieka Films', 'Zabriskie Films']
# ['Renn Productions', 'ARD Degeto', 'D. A. Films', 'WMG Film', 'NEF Filmproduktion', 'RCS Films', 'France 2 Cinéma']
# ['Creative Scotland', 'BFI', 'BFI Film Fund', 'Entertainment One', 'Fable Pictures', 'Film4 Productions', 'WR Holdings', 'Sierra Pictures (II)']
# ['Wild Bunch', 'A Grand Elephant', 'Bold Films', 'Gaumont', 'Film i Väst']
# ['Vision P.D.G.']
# ['Hong Hai Film Productions Limited']
# ['New Century Producers', 'Itami Productions']
# ['Walden Productions', 'Desilu Productions']
# ['Cinemagic', 'Saga Film', 'American International Pictures', 'Sidney Pink Production']
# ['Imagine Entertainment', 'Universal 1440 Entertainment', 'Universal Animation Studios']
# ['Paramount', 'Brooklyn Films II', 'Riff Raff Film Productions', 'Filmauro', 'Blue Flower Productions']
# ['Cinema Group Ventures', 'Phoenix (II)']
# ['Unstoppable Entertainment', 'The Fyzz', 'Tea Shop & Film Company']
# ['Nikkatsu Corporation', 'Fever Dreams']
# ['Golan-Globus Productions', 'Metro-Goldwyn-Mayer', 'Cannon Group']
# ['Hollywood Thailand', 'Thongkham Films', 'Airspeed Pictures', 'Right Beyond', 'Epic Pictures Group']
# ['20th Century Fox', 'Scott Free Productions', 'Brandywine Productions', 'TSG Entertainment']
# ['SCOPE Pictures', 'IMAV Editions', 'Fidélité Films', 'Mandarin Cinéma', 'OCS']
# ['Serena Films', 'Animus Films', 'PalmStar Media']
# ['SModcast Pictures', 'View Askew Productions', 'Miramax', 'Saban Films', 'Destro Films', 'Hideout Pictures', 'Intercut Capital', 'Lions Gate Films']
# ['STUDIO RIKKA', 'Directions']
# ['Mundy Lane Entertainment', 'TriStar Pictures', 'Clinica Estetico']
# ['Yang & His Gang Filmmakers']
# ['Mediaworks', 'Live Entertainment', 'Dinamo Entertainment']
# ['Syfy', 'USA Network']
# ['Artémis Productions', 'Le Pacte', 'Chaz Productions', 'France 3 Cinéma']
# ['Miramax', 'Harbour Pictures', 'Price Productions']
# ['Polytel', 'The Who Films']
# ['Constantin Film', 'Claussen+Wöbke Filmproduktion', 'Mythos Film']
# ['Killer Films', 'Orion Pictures', 'Andrew Lauren Productions', 'Amazon Studios', 'Metro-Goldwyn-Mayer']
# ['SSS Entertainment', 'El Ride Productions', 'Lucidity Entertainment', 'Vertical Entertainment']
# ['Worldwide Pants', 'Levantine Entertainment']
# ['UGC']
# ['Glen A. Larson Productions', 'Universal Television']
# ['Beijing Guoli Changsheng Movies & TV Productions Co.', 'China Film Group', '东阳坏猴子影视文化传播有限公司', 'Emperor Film and Entertainment']
# ['Hombre Productions', '20th Century Fox']
# ['Bewitched', 'Red Wagon Entertainment', 'Columbia Pictures']
# ['XYZ Films', 'Bullet Pictures', 'Mensch Productions', 'Ralfish Films']
# ['United Artists', 'Algonquin']
# ['Wild Bunch', 'Sayaka Producciones Audiovisuales', 'Apaches Entertainment', 'LA Panda', 'Atresmedia', 'SpectreVision']
# ['Universal Pictures', 'WT2 Productions']
# ['Management Company Entertainment Group (MCEG)', 'Hollywood Licensing Group']
# ['DEFA', 'Filmové studio Barrandov']
# ['20th Century Fox Brazil', 'CINE Cinematográfica', 'Estação Luz Filmes']
# ['Chernin Entertainment', 'Feigco Entertainment', '20th Century Fox']
# ['Centropolis Film Productions']
# ['Maipo Film', 'uMedia']
# ['China 3D Digital Entertainment', 'Quidam Studios', 'Zhongmeng Century Media', 'Beijing ShengShi HuaRei Film Investment & Management Co.']
# ['Firelight Films']
# ['Miramax', 'Nina Saxon Film Design', 'FilmColony']
# ['Pyramide Films', 'Historias Cinematográficas', 'Wanda Visión', 'Ministerio de Cultura', 'Cinéfondation', 'Fonds Sud Cinéma']
# ['Rooks Nest Entertainment', 'Rumble Films', 'Backup Media', 'Paradise City', 'Memento Films International', 'Fairmount Films']
# ['VMI Worldwide', 'Minds Eye Entertainment', 'Creativity Capital', 'Bridgegate Pictures', 'Invico Capital']
# ['Unity Productions', 'Universal Pictures']
# ['Esparza Caldera', 'La Victoria Films']
# ['Robbins Entertainment', 'Titan Global Entertainment']
# ['Miramax', 'Independent Pictures (II)', 'The Alfred Shay Company Inc.']
# ['Atresmedia', 'Amiguetes Entertainment']
# ['Double Dutch International', 'Elgin Road Productions', 'Awesometown Entertainment']
# ['ELC Productions Ltd.', 'Alan Greenspan Productions', 'Mars Media Beteiligungs', 'Fox 2000 Pictures', 'Flower Films', 'Wildgaze Films']
# ['Forensic Films', 'Symbolic Exchange', 'Bellmer Pictures']
# ['Above the Clouds Media Group', 'CaliWood Pictures', '120dB Films']
# ['Turner Network Television', 'Haft Entertainment', 'St. Nick Productions']
# ['Red Breast Productions', 'Bankside Films', 'Head Gear Films', 'Metrol Technology', 'Lunapark Pictures', 'IFC Productions', 'Blue Bear Film & TV']
# ['Fulwell 73', 'Rocket Entertainment']
# ['Final Cut for Real', 'ARTE', 'RYOT Films', 'Det Danske Filminstitut', 'Svenska Filminstitutet', 'Norsk Filminstitutt', 'Nordisk Film & TV Fond', 'Den Vestdanske Filmpulje', 'MEDIA sub-programme of Creative Europe', 'Région Bretagne', 'Pictanovo', 'CNC', 'La Procirep-Angoa', 'Mer Film AS', 'VICE Media', 'Copenhagen Film Fund', 'DR', 'The Fritt Ord Foundation', 'I Wonder Pictures', 'Movistar+', 'Cinephil', 'Left Handed Films', 'SVT', 'Vivement lundi !', 'Sun Creature', 'Participant']
# ['Stolen Picture', 'Catalyst Global Media', 'Sony Pictures International Productions']
# ['Sycamore Pictures', 'OddLot Entertainment', 'The Walsh Company', 'What Just Happened Productions']
# ['FilmMcQueen', 'Soul Kiss Films']
# ['Skydance Animation', 'Skydance Animation']
# ['Huanxi Media Group', 'Wanda Pictures', 'Alibaba Pictures Group', '东阳坏猴子影视文化传播有限公司']
# ['William Castle Productions', 'Allied Artists Pictures']
# ['Boll Kino Beteiligungs GmbH & Co. KG', 'Brightlight Pictures', 'Pitchblack Pictures Inc.']
# ['a.k.a. Cartoon', 'Voice Box Productions']
# ['Octane Entertainment', 'Superchill']
# ['FilmFörderung Hamburg', 'Studio Babelsberg', 'Babelsberg Film', 'Magnolia Filmproduktion', 'Beta Cinema', 'ZDF', 'Aichholzer Film']
# ['Reveal Entertainment', 'Revelations Entertainment', 'Mockingbird Pictures']
# ['Woo Films']
# ['Red Chillies Entertainment', 'Dharma Productions', 'Hope Productions']
# ['XYZ Films', '120dB Films', 'JoBro Productions', 'Cave Painting Pictures', 'The Salt Company']
# ['Karé Productions']
# ['Paramount', 'MTV Films', 'Zomba Films', 'Summit Entertainment']
# ['Project Team Argos', 'Madhouse', 'Magic Capsule', 'Kadokawa Shoten', 'KADOKAWA']
# ['Ruddy Morgan Organization, The', '20th Century Fox']
# ['BBC Film', 'Calamity Films', 'Pathé', 'LD Entertainment', 'Roadside Attractions']
# ['Andre Paulve Film']
# ['Interscope Communications', 'TriStar Pictures', 'Daniel Grodnik Productions']
# ['Magnolia Pictures', '2929 Productions', 'Extension 765']
# ['Periscope Entertainment']
# ['Strike Entertainment', 'Universal Pictures', 'Spyglass Entertainment', 'Intermittent Productions']
# ['Keplerfilm', 'VPRO']
# ['BBC Film']
# ['上海艺言堂影视文化传播有限公司']
# ['MK2 Films', 'Lyla Films']
# ['Silver Screen Partners II', 'Touchstone Pictures']
# ['Artists Public Domain', 'Fox Searchlight Pictures']
# ['Nitelite Entertainment', 'Full Paige']
# ['Películas Grupo Tranquilo', 'Sacromonte Films']
# ['FOZ', 'France 2 Cinéma', 'Playtime', 'SCOPE Pictures', 'Mandarin Cinéma', 'Cohen Media Group']
# ['Brain Power Studio']
# ['Epic Level Entertainment', 'Roxwell Films']
# ['Indigo Film', 'RAI']
# ['Cinemora Pictures']
# ['Actionhouse Pictures', 'Hollywood Media Bridge', 'Shadow Vale Productions']
# ['Fox Searchlight Pictures', 'Free Range Films', 'TSG Entertainment']
# ['FNM Films', 'Harvey Bernhard Productions', 'Mace Neufeld Productions']
# ['Motion Picture Group, The']
# ['Millennium Films', 'Principato-Young Entertainment', 'Nu Boyana Film Studios', 'Sunset Junction Entertainment']
# ['Jessie Nelson Productions', 'Silver Pictures', 'David Dobkin Productions', 'Warner Bros. Pictures']
# ['MACA Entretenimento', 'TLA Releasing']
# ['Frontera Films S.A.']
# ['Mofac', 'Next Entertainment World', 'Yworks Entertainment']
# ['RADiUS-TWC', 'Duplass Brothers Productions']
# ['ICAA', 'Himenóptero', 'Mod Producciones', 'Telecinco Cinema', 'Canal+ España', 'Fox International Productions', 'Focus Features', 'Hispano Foxfilms S.A.E.', 'Calle Cruzada']
# ['CJ Entertainment', 'Sidus']
# ['CiBy 2000', 'Pandora Film', 'Komuna']
# ['CG Cinéma', 'Nostromo Pictures', 'RT Features', 'SCOPE Pictures', 'France 2 Cinéma', 'Orange Studio', 'Memento Films Production']
# ['WarParty Films']
# ['Silver Screen Partners IV', 'Touchstone Pictures']
# ['Sunshine Pictures', 'Pen India Limited']
# ['Gorilla 8 Productions', 'Nova Film']
# ['Motlys', 'Coproduction Office', 'Film i Väst', 'Plattform Produktion', 'Parisienne', 'Auvergne-Rhône-Alpes Cinéma']
# ['Bandai Visual', 'Production I.G', 'Bandai Namco Games']
# ['Tri-Star-Delphi III Productions', 'Pluperfect', 'Columbia Pictures']
# ['Diamond Docs', 'Oceanic Preservation Society', 'ReFuel Productions']
# ['Lost City', 'Good Universe', 'MXN Entertainment']
# ['American Zoetrope', 'NALA Films', 'StudioCanal', 'Tohokushinsha Film Corporation', 'Tobis Film', 'FilmNation Entertainment', 'Pathé']
# ['American Zoetrope', 'Warner Bros. Pictures', 'Warner Bros. Family Entertainment']
# ['The Contents On', 'EchoFilm', 'Merry Christmas', 'The Pictures with a View', 'Finecut']
# ['Black Bear Pictures']
# ['Sigma Film Productions', 'Boudica Films']
# ['Nippon Television Network Corporation', 'VAP', 'Tohokushinsha Film Corporation', 'Kyokuichi-Tokyo Movie']
# ['Intrepid Pictures', 'Platinum Dunes', 'Focus Features']
# ['Yellow Brick Films', 'f8 Films', 'SkyWolf Media', 'Renegade Entertainment', 'Brigade Media Capital']
# ['Lawrence Bender Productions']
# ['E-K-Corporation', 'United Artists', "Lion's Gate Films"]
# ['Paul Schiff Productions', 'Smartest Man Productions', 'Millennium Films']
# ['KIT Film Studio', 'Studio Trite', 'Kinoslovo', 'Gazprom-Media', 'Cinema Fund']
# ['Morgan Creek Productions', '20th Century Fox']
# ['Miramax', 'WingNut Films', 'New Zealand Film Commission', 'Fontana Productions']
# ['IM Global Octane', 'Blumhouse Productions', 'Dimension Films', 'Busted Shark Productions', 'Chapter One Films']
# ['Paramount', 'Universal Pictures', 'Film Properties International N.V.']
# ['Huaxia Film Distribution Company', 'Bona Film Group', 'August 1st Film Studio']
# ['ProdigyMovies', 'Australian Film Commission', 'Territorial Film Developments (TFD)', 'Mysterious Light']
# ['Aeroplano Cine', 'Sobras International Pictures', 'Telefe', 'World Pictures', 'Comedy Central', 'INCAA', 'Movie Trucks', 'Non Stop']
# ['Talent Network Media GmbH', 'International West Pictures (IWP)', 'Original Voices Inc.', 'Motion Picture Corporation of America']
# ['Intrinsic Value Films', 'Sumerian Films', 'Jeff Rice Films']
# ['Rastar Productions']
# ['Studio Images 6', 'Fidélité Productions', 'Les Films Alain Sarde', 'Eurospace']
# ['Acemaker Movieworks', 'Danacreative']
# ['Ealing Studios', 'Fragile Films', 'Entertainment Film Distributors', 'UK Film Council']
# ['Baby Cow Productions', 'BBC Film', 'Ingenious Media', 'Creative Scotland', 'Pathé']
# ['Burn Later Productions', 'Meridian Content', 'Universal Pictures']
# ['Kodansha']
# ['Why Not Productions', 'Wild Bunch', 'Sixteen Films', 'Les Films du Fleuve', 'BFI', 'BBC Film']
# ['IDT Entertainment', 'Film Roman']
# ['Dark Castle Entertainment', 'Warner Premiere']
# ['Zephyr Films', 'A Contracorriente Films', 'Diagonal TV']

# %%
#Q25

# Sort the IDs in ascending order
sorted_data = ds.sort_values('id')

# Display the sorted IDs
sorted_ids = sorted_data['id'].tolist()
print(sorted_ids)
# Out:
# [5, 11, 12, 13, 14, 15, 16, 18, 19, 22, 24, 25, 27, 28, 33, 35, 38, 55, 58, 59, 62, 63, 64, 65, 66, 68, 69, 70, 71, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 85, 87, 88, 89, 90, 93, 95, 96, 97, 98, 101, 103, 104, 105, 106, 107, 108, 109, 110, 111, 114, 115, 116, 117, 118, 120, 121, 122, 123, 128, 129, 134, 136, 137, 138, 141, 142, 143, 144, 145, 146, 147, 149, 150, 152, 153, 154, 155, 157, 158, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 172, 173, 174, 175, 176, 178, 179, 180, 184, 185, 186, 187, 189, 192, 194, 196, 197, 199, 200, 201, 203, 205, 207, 213, 214, 215, 217, 218, 219, 221, 223, 226, 227, 229, 231, 233, 234, 235, 236, 238, 239, 240, 241, 242, 243, 244, 247, 251, 252, 253, 254, 257, 262, 268, 269, 272, 275, 277, 278, 279, 280, 284, 285, 287, 288, 289, 290, 293, 296, 297, 298, 301, 306, 310, 311, 314, 319, 320, 322, 326, 329, 332, 334, 335, 336, 338, 345, 346, 348, 350, 363, 364, 377, 378, 379, 380, 387, 388, 389, 391, 392, 393, 395, 396, 401, 402, 403, 404, 405, 406, 408, 409, 411, 414, 415, 421, 422, 423, 424, 425, 426, 429, 431, 433, 435, 437, 439, 440, 451, 452, 453, 454, 455, 458, 462, 468, 470, 475, 479, 482, 483, 488, 489, 490, 492, 496, 497, 500, 503, 504, 506, 508, 509, 510, 521, 524, 525, 526, 530, 531, 533, 534, 535, 539, 540, 542, 544, 547, 550, 551, 553, 557, 558, 559, 561, 562, 563, 564, 565, 567, 568, 571, 573, 576, 578, 579, 580, 581, 582, 583, 585, 586, 587, 588, 591, 593, 594, 595, 597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 612, 613, 615, 616, 617, 619, 620, 621, 622, 623, 624, 627, 628, 629, 630, 634, 635, 637, 638, 639, 640, 641, 642, 644, 646, 647, 648, 649, 650, 651, 652, 653, 654, 655, 657, 658, 659, 660, 663, 664, 665, 667, 668, 670, 671, 672, 673, 674, 675, 676, 679, 680, 681, 682, 686, 687, 688, 691, 692, 693, 694, 698, 699, 700, 702, 703, 705, 707, 708, 709, 710, 711, 712, 713, 714, 744, 745, 746, 747, 752, 754, 755, 756, 759, 762, 763, 764, 765, 766, 767, 768, 769, 770, 772, 773, 775, 780, 782, 783, 786, 787, 788, 790, 791, 792, 793, 794, 795, 796, 797, 801, 802, 804, 805, 806, 807, 808, 809, 810, 812, 813, 814, 816, 817, 818, 819, 820, 821, 823, 824, 826, 829, 830, 832, 834, 837, 838, 839, 840, 841, 843, 844, 845, 846, 847, 849, 853, 854, 855, 856, 857, 858, 859, 860, 861, 862, 863, 864, 865, 866, 867, 869, 871, 872, 873, 877, 879, 881, 884, 887, 888, 889, 891, 892, 895, 900, 901, 902, 903, 907, 910, 912, 913, 914, 916, 918, 920, 921, 923, 924, 925, 926, 927, 928, 929, 931, 935, 936, 938, 941, 942, 943, 944, 947, 948, 949, 950, 951, 953, 954, 955, 956, 957, 962, 963, 966, 967, 968, 975, 978, 979, 980, 982, 984, 985, 987, 990, 996, 1018, 1024, 1040, 1051, 1075, 1089, 1090, 1091, 1092, 1093, 1103, 1124, 1125, 1164, 1165, 1213, 1245, 1246, 1247, 1249, 1250, 1251, 1255, 1259, 1265, 1266, 1267, 1268, 1271, 1272, 1273, 1278, 1281, 1283, 1285, 1359, 1360, 1362, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1374, 1375, 1378, 1381, 1389, 1391, 1396, 1398, 1402, 1406, 1407, 1408, 1412, 1417, 1422, 1427, 1428, 1429, 1430, 1433, 1440, 1443, 1450, 1452, 1487, 1491, 1492, 1493, 1494, 1495, 1497, 1498, 1499, 1523, 1534, 1538, 1541, 1542, 1544, 1547, 1548, 1551, 1562, 1568, 1571, 1572, 1573, 1574, 1576, 1577, 1578, 1579, 1580, 1581, 1584, 1585, 1586, 1587, 1588, 1592, 1593, 1597, 1598, 1600, 1607, 1620, 1621, 1624, 1626, 1630, 1631, 1633, 1634, 1635, 1636, 1637, 1639, 1640, 1642, 1643, 1644, 1645, 1646, 1648, 1649, 1653, 1654, 1656, 1669, 1677, 1678, 1679, 1680, 1683, 1685, 1687, 1688, 1689, 1690, 1691, 1694, 1696, 1700, 1701, 1705, 1710, 1712, 1715, 1721, 1724, 1725, 1726, 1729, 1730, 1734, 1735, 1738, 1771, 1777, 1788, 1791, 1807, 1808, 1813, 1817, 1824, 1825, 1830, 1832, 1844, 1847, 1852, 1857, 1858, 1865, 1870, 1878, 1879, 1880, 1883, 1884, 1885, 1887, 1890, 1891, 1892, 1893, 1894, 1895, 1900, 1902, 1903, 1904, 1907, 1911, 1921, 1923, 1924, 1927, 1930, 1931, 1933, 1934, 1936, 1941, 1946, 1948, 1949, 1954, 1955, 1957, 1965, 1966, 1968, 1969, 1970, 1975, 1977, 1979, ...

# %%
#Q26
high_budget_low_rate = ds.query('budget > 100000000 and vote_average < 5')
high_budget_low_rate
# Out:
#           id                                          title release_date  \
# 23    385687                                         Fast X   2023-05-17
# 128   667538               Transformers: Rise of the Beasts   2023-06-07
# 184   298618                                      The Flash   2023-06-14
# 1142   10196                             The Last Airbender   2010-06-30
# 1266  335977          Indiana Jones and the Dial of Destiny   2023-06-28
# 1849  166424                                 Fantastic Four   2015-08-05
# 2408  575264  Mission: Impossible - Dead Reckoning Part One   2023-07-10
# 3476  565770                                    Blue Beetle   2023-08-16
# 3483     415                                 Batman & Robin   1997-06-20
# 4798    1639                        Speed 2: Cruise Control   1997-06-13
# 4953  393209                                       Avatar 5   2028-12-20
# 5586  787699                                          Wonka   2023-12-13
# 5587  466420                     Killers of the Flower Moon   2023-10-06
# 5939   83533                                       Avatar 3   2024-12-18
#
#                                                  genres original_language  \
# 23                      ['Action', 'Crime', 'Thriller']           English
# 128          ['Action', 'Adventure', 'Science Fiction']           English
# 184          ['Science Fiction', 'Action', 'Adventure']           English
# 1142                 ['Action', 'Adventure', 'Fantasy']           English
# 1266                            ['Adventure', 'Action']           English
# 1849         ['Action', 'Adventure', 'Science Fiction']           English
# 2408                ['Action', 'Adventure', 'Thriller']           English
# 3476                      ['Action', 'Science Fiction']           English
# 3483  ['Action', 'Science Fiction', 'Adventure', 'Co...           English
# 4798                ['Action', 'Adventure', 'Thriller']           English
# 4953         ['Action', 'Adventure', 'Science Fiction']           English
# 5586                  ['Adventure', 'Comedy', 'Family']           English
# 5587                     ['Crime', 'Drama', 'Thriller']           English
# 5939         ['Action', 'Science Fiction', 'Adventure']           English
#
#       vote_average  vote_count  popularity       budget  \
# 23             0.0           0     732.647  340000000.0
# 128            0.0           0     222.430  200000000.0
# 184            0.0           0     123.659  220000000.0
# 1142           4.7        3585      36.621  150000000.0
# 1266           0.0           0      42.876  294700000.0
# 1849           4.4        5525      32.330  120000000.0
# 2408           0.0           0      30.128  290000000.0
# 3476           0.0           0      22.946  120000000.0
# 3483           4.3        4485      24.492  125000000.0
# 4798           4.6        1429      20.277  160000000.0
# 4953           0.0           0      16.033  250000000.0
# 5586           0.0           0      14.106  125000000.0
# 5587           0.0           0      14.445  200000000.0
# 5939           0.0           0      11.996  250000000.0
#
#                                    production_companies vote_category
# 23    ['Universal Pictures', 'Original Film', 'One R...           bad
# 128   ['Skydance Media', 'Paramount', 'di Bonaventur...           bad
# 184   ['Warner Bros. Pictures', 'Double Dream', 'The...           bad
# 1142  ['Paramount', 'Nickelodeon Movies', 'Blinding ...           bad
# 1266  ['Lucasfilm Ltd.', 'Walt Disney Pictures', 'Pa...           bad
# 1849  ['Moving Picture Company', 'Marvel Entertainme...           bad
# 2408  ['Paramount', 'Skydance Media', 'New Republic ...           bad
# 3476  ['Warner Bros. Pictures', 'The Safran Company'...           bad
# 3483  ['DC Comics', 'PolyGram Filmed Entertainment',...           bad
# 4798     ['Blue Tulip Productions', '20th Century Fox']           bad
# 4953  ['Lightstorm Entertainment', '20th Century Stu...           bad
# 5586          ['Warner Bros. Pictures', 'Heyday Films']           bad
# 5587  ['Appian Way', 'Imperative Entertainment', 'Si...           bad
# 5939  ['Lightstorm Entertainment', '20th Century Stu...           bad

# %%
#Q27
high_rate_low_budget = ds.query('vote_average > 8 and budget < 10000000')
high_rate_low_budget
# Out:
#           id                                 title release_date  \
# 56    820067  The Quintessential Quintuplets Movie   2022-05-20
# 164   637920                 Miracle in Cell No. 7   2019-10-10
# 192   372058                            Your Name.   2016-08-26
# 207   851644                     20th Century Girl   2022-10-06
# 237   400928                                Gifted   2017-04-12
# ...      ...                                   ...          ...
# 9814   15804                 A Brighter Summer Day   1991-07-27
# 9817  823754                    Bo Burnham: Inside   2021-07-22
# 9847  612304          Divaldo: O Mensageiro da Paz   2019-09-12
# 9861  654299             Out of the Clear Blue Sky   2019-12-24
# 9883  532753                      Dying to Survive   2018-07-06
#
#                                   genres original_language  vote_average  \
# 56    ['Animation', 'Comedy', 'Romance']          Japanese           8.6
# 164                            ['Drama']           Turkish           8.3
# 192    ['Romance', 'Animation', 'Drama']          Japanese           8.5
# 207                 ['Romance', 'Drama']            Korean           8.4
# 237                  ['Drama', 'Comedy']           English           8.1
# ...                                  ...               ...           ...
# 9814       ['Crime', 'Drama', 'Romance']           Chinese           8.3
# 9817                 ['Comedy', 'Drama']           English           8.2
# 9847                           ['Drama']        Portuguese           8.3
# 9861        ['Comedy', 'Drama', 'Music']           Spanish           8.2
# 9883                 ['Drama', 'Comedy']           Chinese           8.1
#
#       vote_count  popularity     budget  \
# 56           235     287.143   370000.0
# 164         4125     128.270   370000.0
# 192         9777     139.896   370000.0
# 207          448     138.051      119.0
# 237         4788      96.766  7000000.0
# ...          ...         ...        ...
# 9814         245      11.905   370000.0
# 9817         353      10.014   370000.0
# 9847          59      16.640   370000.0
# 9861         314      11.296   370000.0
# 9883         117      10.290   370000.0
#
#                                    production_companies vote_category
# 56    ['DAX Production', 'Pony Canyon', 'Nichion', '...          good
# 164   ['Lanistar Media', 'Motion Content Group', 'CJ...          good
# 192   ['CoMix Wave Films', 'TOHO', 'KADOKAWA', 'East...          good
# 207                                       ['Yong Film']          good
# 237   ['Grade A Entertainment', 'Dayday Films', 'Fil...          good
# ...                                                 ...           ...
# 9814                     ['Yang & His Gang Filmmakers']          good
# 9817                                          Company X          good
# 9847  ['20th Century Fox Brazil', 'CINE Cinematográf...          good
# 9861           ['Esparza Caldera', 'La Victoria Films']          good
# 9883  ['Huanxi Media Group', 'Wanda Pictures', 'Alib...          good
#
# [208 rows x 11 columns]

# %%
#Q28
movies_with_rating_8 = ds[ds['vote_average'] == 8]['title']
movies_with_rating_8
# Out:
# 22      Justice League x RWBY: Super Heroes & Huntsmen...
# 68                                Spider-Man: No Way Home
# 78          Demon Slayer: Kimetsu no Yaiba Sibling's Bond
# 103                                                Suzume
# 133          Swapping: A Divorce Trip Between Two Couples
#                               ...
# 9207                                            La Strada
# 9283                                        Autumn Sonata
# 9380                         Date A Live: Mayuri Judgment
# 9437                Inazuma Eleven Go vs. Danball Senki W
# 9809                          La leyenda del Charro Negro
# Name: title, Length: 113, dtype: object

# %%
#Q29
min_release_date = ds['release_date'].min()
movie_with_min_release_date = ds[ds['release_date'] == min_release_date]['title']
movie_with_min_release_date
# Out:
# 5527    A Trip to the Moon
# Name: title, dtype: object

# %%
#Q30
max_release_date = ds['release_date'].max()
movie_with_max_release_date = ds[ds['release_date'] == max_release_date]['title']
movie_with_max_release_date
# Out:
# 4953    Avatar 5
# Name: title, dtype: object

# %%
ds.describe()
# Out:
#                  id  vote_average    vote_count   popularity        budget
# count  9.979000e+03   9979.000000   9979.000000  9979.000000  9.979000e+03
# mean   3.143436e+05      6.338822   1530.054915    31.488106  1.972519e+07
# std    3.331747e+05      1.388166   2870.875959   111.528200  3.881205e+07
# min    5.000000e+00      0.000000      0.000000     7.219000  1.000000e+00
# 25%    1.220300e+04      5.900000    123.000000    13.531500  3.700000e+05
# 50%    1.925770e+05      6.500000    483.000000    17.616000  3.700000e+05
# 75%    5.604590e+05      7.100000   1561.000000    27.175500  2.200000e+07
# max    1.119921e+06     10.000000  33633.000000  5089.969000  5.793304e+08

# %%
ds.shape
# Out:
# (9979, 11)

# %%
import seaborn as sns
sns.boxplot (x="budget", data=ds)
# Out:
# <Axes: xlabel='budget'>

# %%
ds["new_budget"] = ds["budget"].apply(np.log)
ds
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity       budget  \
# 0              7.4         619    5089.969   18000000.0
# 1              6.6        2294    4665.438  200000000.0
# 2              7.5        1861    3935.550  100000000.0
# 3              7.2         652    2791.532     370000.0
# 4              6.8        1510    2702.593  125000000.0
# ...            ...         ...         ...          ...
# 9995           7.7        1220      10.774     370000.0
# 9996           6.3          99      12.739     370000.0
# 9997           5.6         263      12.769     370000.0
# 9998           5.0           5      10.425     370000.0
# 9999           6.5         382      12.525    5400000.0
#
#                                    production_companies vote_category  \
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...          good
# 1         ['Marvel Studios', 'Kevin Feige Productions']          good
# 2     ['Universal Pictures', 'Illumination', 'Ninten...          good
# 3                   ['Skydance Media', 'Apple Studios']          good
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...          good
# ...                                                 ...           ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...          good
# 9996                ['IDT Entertainment', 'Film Roman']          good
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']           bad
# 9998                                          Company X           bad
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...          good
#
#       new_budget
# 0      16.705882
# 1      19.113828
# 2      18.420681
# 3      12.821258
# 4      18.643824
# ...          ...
# 9995   12.821258
# 9996   12.821258
# 9997   12.821258
# 9998   12.821258
# 9999   15.501910
#
# [9979 rows x 12 columns]

# %%
import seaborn as sns
sns.boxplot (x="new_budget", data=ds)
# Out:
# <Axes: xlabel='new_budget'>

# %%
ds = ds.drop('budget',axis=1)
ds
# Out:
#           id                              title release_date  \
# 0     758323                The Pope's Exorcist   2023-04-05
# 1     640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2     502356        The Super Mario Bros. Movie   2023-04-05
# 3     868759                            Ghosted   2023-04-18
# 4     594767           Shazam! Fury of the Gods   2023-03-15
# ...      ...                                ...          ...
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 0                     ['Horror', 'Mystery', 'Thriller']           English
# 1            ['Action', 'Adventure', 'Science Fiction']           English
# 2     ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                       ['Action', 'Comedy', 'Romance']           English
# 4          ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
# ...                                                 ...               ...
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity  \
# 0              7.4         619    5089.969
# 1              6.6        2294    4665.438
# 2              7.5        1861    3935.550
# 3              7.2         652    2791.532
# 4              6.8        1510    2702.593
# ...            ...         ...         ...
# 9995           7.7        1220      10.774
# 9996           6.3          99      12.739
# 9997           5.6         263      12.769
# 9998           5.0           5      10.425
# 9999           6.5         382      12.525
#
#                                    production_companies vote_category  \
# 0     ['Screen Gems', '2.0 Entertainment', 'Jesus & ...          good
# 1         ['Marvel Studios', 'Kevin Feige Productions']          good
# 2     ['Universal Pictures', 'Illumination', 'Ninten...          good
# 3                   ['Skydance Media', 'Apple Studios']          good
# 4     ['New Line Cinema', 'The Safran Company', 'DC ...          good
# ...                                                 ...           ...
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...          good
# 9996                ['IDT Entertainment', 'Film Roman']          good
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']           bad
# 9998                                          Company X           bad
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...          good
#
#       new_budget
# 0      16.705882
# 1      19.113828
# 2      18.420681
# 3      12.821258
# 4      18.643824
# ...          ...
# 9995   12.821258
# 9996   12.821258
# 9997   12.821258
# 9998   12.821258
# 9999   15.501910
#
# [9979 rows x 11 columns]

# %%
ds.to_csv('C:\\Users\\El-Wattaneya\\Desktop\\popular_10000_movies_tmdb.csv', index=False)

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
sns.set(rc={'figure.figsize':[10,10]},font_scale=1.2)

sns.countplot(y='original_language',data=ds)
# Out:
# <Axes: xlabel='count', ylabel='original_language'>

# %%
sns.barplot(x='vote_category',y='vote_count',data=ds,estimator=np.mean)
# Out:
# <Axes: xlabel='vote_category', ylabel='vote_count'>

# %%
sns.heatmap(ds.corr(),annot=True)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_18480\1221165314.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ds.corr(),annot=True)
# <Axes: >

# %%
ds['vote_category'].value_counts()
# Out:
# good    7010
# bad     2969
# Name: vote_category, dtype: int64

# %%
ds.groupby('vote_count').mean()['new_budget']
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_18480\3843759550.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ds.groupby('vote_count').mean()['new_budget']
# vote_count
# 0        13.097896
# 1        12.714703
# 2        12.594753
# 3        12.898500
# 4        12.772057
#            ...
# 28543    19.209138
# 29040    19.283571
# 29634    19.035866
# 31296    18.921456
# 33633    18.890684
# Name: new_budget, Length: 3447, dtype: float64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

ds = pd.read_csv("popular_10000_movies_tmdb.csv")


# Step 1: Prepare the Data

# Extract the feature (X) and target variable (y)
X = ds["vote_average"]
y = ds["vote_category"]

# Step 2: Split the Data into Training and Test Sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3: Encode the Target Variable
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Reshape the input data from 1D to 2D
X_train = X_train.values.reshape(-1, 1)
X_test = X_test.values.reshape(-1, 1)

# Step 4: Initialize the Classifier
classifier = LogisticRegression()

# Step 5: Train the Model
classifier.fit(X_train, y_train_encoded)

# Step 6: Predict and Evaluate
y_pred = classifier.predict(X_test)

# Step 7: Calculate Accuracy
accuracy = accuracy_score(y_test_encoded, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0
